# %%
print("Hello from Data Mining Laboratory")
# Out:
# Hello from Data Mining Laboratory

# %% [markdown]
# Fake Dataset creation using Faker library. This Dataset consists of 10000 rows and 6 columns describing faje transactions of buying Personal Computer (PC) components in USA cities.

# %%
import random
from faker import Faker
import pandas as pd

faker = Faker()

# Expanding the list of components and accessories
components = [
    'CPU', 'GPU', 'Motherboard', 'RAM', 'SSD', 'HDD', 'Power Supply',
    'Case', 'Cooling Fan', 'Monitor', 'Keyboard', 'Mouse', 'Speakers',
    'Headset', 'Graphics Tablet', 'Webcam', 'Optical Drive', 'Thermal Paste',
    'CPU Cooler', 'RGB Lighting', 'Sound Card', 'Network Card', 'UPS',
    'Surge Protector', 'External HDD', 'USB Hub'
]

def generate_pc_build_data(num_entries=1000):
    data = []
    cities = [
        "New York City, NY",
        "Los Angeles, CA",
        "Chicago, IL",
        "Houston, TX",
        "Phoenix, AZ",
        "Philadelphia, PA",
        "San Antonio, TX",
        "San Diego, CA",
        "Dallas, TX",
        "San Jose, CA",
        "Austin, TX",
        "Jacksonville, FL",
        "San Francisco, CA",
        "Columbus, OH",
        "Indianapolis, IN",
        "Fort Worth, TX",
        "Charlotte, NC",
        "Seattle, WA",
        "Denver, CO",
        "El Paso, TX",
        "Detroit, MI"
    ]

    user_ids = {}
    city_assignments = {}
    transaction_id = 1

    while len(data) < num_entries:
        person = faker.name()

        # Assign a unique user_id to each person
        if person not in user_ids:
            user_ids[person] = f"USER{len(user_ids) + 1:04}"
            # Assign a city to this new user
            city_assignments[user_ids[person]] = random.choice(cities)
        user_id = user_ids[person]

        for _ in range(random.randint(1, 5)):  # Each person may make 1 to 5 purchases
            if len(data) >= num_entries:
                break  # Stop if we've reached the desired number of entries

            date = faker.date_between(start_date='-2y', end_date='today')
            city = city_assignments[user_id]
            # Random selection of components
            purchased_items = random.sample(
                components, k=random.randint(3, 10))

            data.append({
                'user_id': user_id,
                'transaction_id': f"TX{transaction_id:05}",
                'person': person,
                'date': date,
                'city': city,
                'purchased_items': ','.join(purchased_items)
            })
            transaction_id += 1

    return pd.DataFrame(data)

# Generate the dataset
expanded_pc_build_data = generate_pc_build_data(10000)
expanded_pc_build_data
# Out:
#        user_id transaction_id           person        date               city  \
# 0     USER0001        TX00001  Michele Griffin  2022-11-20        Houston, TX
# 1     USER0001        TX00002  Michele Griffin  2024-07-04        Houston, TX
# 2     USER0001        TX00003  Michele Griffin  2022-10-18        Houston, TX
# 3     USER0002        TX00004   Lisa Christian  2024-05-31        Detroit, MI
# 4     USER0002        TX00005   Lisa Christian  2022-10-18        Detroit, MI
# ...        ...            ...              ...         ...                ...
# 9995  USER3285        TX09996    Johnny Thomas  2022-10-02  New York City, NY
# 9996  USER3285        TX09997    Johnny Thomas  2023-05-11  New York City, NY
# 9997  USER3285        TX09998    Johnny Thomas  2024-01-16  New York City, NY
# 9998  USER3286        TX09999      Marie Berry  2023-03-04        Chicago, IL
# 9999  USER3286        TX10000      Marie Berry  2024-04-15        Chicago, IL
#
#                                         purchased_items
# 0     External HDD,CPU,USB Hub,Keyboard,Mouse,Power ...
# 1         Motherboard,Thermal Paste,UPS,Graphics Tablet
# 2     CPU,Motherboard,Surge Protector,GPU,Cooling Fa...
# 3         Power Supply,External HDD,Sound Card,Speakers
# 4     Thermal Paste,CPU,Surge Protector,Motherboard,...
# ...                                                 ...
# 9995           Monitor,RAM,USB Hub,Cooling Fan,Case,UPS
# 9996       Sound Card,Optical Drive,Mouse,Thermal Paste
# 9997  Headset,SSD,RAM,USB Hub,Optical Drive,Webcam,P...
# 9998     Monitor,Headset,Speakers,Motherboard,Mouse,CPU
# 9999  Power Supply,CPU,Speakers,USB Hub,Monitor,Cool...
#
# [10000 rows x 6 columns]

# %%
expanded_pc_build_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          10000 non-null  object
#  1   transaction_id   10000 non-null  object
#  2   person           10000 non-null  object
#  3   date             10000 non-null  object
#  4   city             10000 non-null  object
#  5   purchased_items  10000 non-null  object
# dtypes: object(6)
# memory usage: 468.9+ KB

# %% [markdown]
# Saving the dataset into a csv file

# %%
expanded_pc_build_data.to_csv('expanded_pc_build_data.csv')

# %%
unique_customers = expanded_pc_build_data['user_id'].nunique()
print(f"Number of unique customers: {unique_customers}")
# Out:
# Number of unique customers: 3210

# %% [markdown]
# Reading the dataset from the saved csv file and displaying the first 5 rows

# %%
import pandas as pd
from prettytable import PrettyTable
df = pd.read_csv('./expanded_pc_build_data.csv')[:1000]
df.head()
# Out:
#    Unnamed: 0   user_id transaction_id           person        date  \
# 0           0  USER0001        TX00001  Michele Griffin  2022-11-20
# 1           1  USER0001        TX00002  Michele Griffin  2024-07-04
# 2           2  USER0001        TX00003  Michele Griffin  2022-10-18
# 3           3  USER0002        TX00004   Lisa Christian  2024-05-31
# 4           4  USER0002        TX00005   Lisa Christian  2022-10-18
#
#           city                                    purchased_items
# 0  Houston, TX  External HDD,CPU,USB Hub,Keyboard,Mouse,Power ...
# 1  Houston, TX      Motherboard,Thermal Paste,UPS,Graphics Tablet
# 2  Houston, TX  CPU,Motherboard,Surge Protector,GPU,Cooling Fa...
# 3  Detroit, MI      Power Supply,External HDD,Sound Card,Speakers
# 4  Detroit, MI  Thermal Paste,CPU,Surge Protector,Motherboard,...

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  1000.000000
# mean    499.500000
# std     288.819436
# min       0.000000
# 25%     249.750000
# 50%     499.500000
# 75%     749.250000
# max     999.000000

# %%
unique_user_ids = df['user_id'].unique()
unique_items = []
for index, rows in df.iterrows():
    for item in rows['purchased_items'].split(','):
        if item not in unique_items:
            unique_items.append(item)

unique_items
# Out:
# ['External HDD',
#  'CPU',
#  'USB Hub',
#  'Keyboard',
#  'Mouse',
#  'Power Supply',
#  'Headset',
#  'Optical Drive',
#  'Motherboard',
#  'Thermal Paste',
#  'UPS',
#  'Graphics Tablet',
#  'Surge Protector',
#  'GPU',
#  'Cooling Fan',
#  'Speakers',
#  'Sound Card',
#  'CPU Cooler',
#  'HDD',
#  'Case',
#  'Network Card',
#  'RGB Lighting',
#  'Monitor',
#  'RAM',
#  'SSD',
#  'Webcam']

# %%
len(unique_items)
# Out:
# 26

# %%
def find_C_1(unique_items:list):
    C = {}
    for i in unique_items:
        C[i] = 0
    
    for index, transaction in df.iterrows():
        items = transaction['purchased_items'].split(',')
        for key, value in C.items():
            if key in items:
                C[key] += 1
    return C

def find_C_2(L1:dict, df:pd.DataFrame)->dict:
    C2 = {}
    Keys = list(L1.keys())
    for i in range(len(Keys)):
        for j in range(i+1, len(Keys)):
            C2[tuple(sorted([Keys[i], Keys[j]]))] = 0
            for index, row in df.iterrows():
                if set ([Keys[i], Keys[j]]).issubset(set(row['purchased_items'].split(','))):
                    C2[tuple(sorted([Keys[i], Keys[j]]))] += 1
    return C2

def find_L(C: dict, min_sup: int) -> dict:
    unsorted_L = {key: value for key, value in C.items() if value >= min_sup}
    Keys = list(unsorted_L.keys())
    Keys.sort()
    sorted_L = {i: unsorted_L[i] for i in Keys}
    return sorted_L

def find_candidate_itemsets_after_L2(L:dict, df:pd.DataFrame, min_sup:int)->dict:
    k = 2  
    current_L = L
    all_frequent_itemsets = {k: current_L}  

    while len(current_L) > 0:
        k += 1
        
        candidate_itemsets = {}
        current_keys = list(current_L.keys())

        
        for i in range(len(current_keys)):
            for j in range(i + 1, len(current_keys)):
               
                union_itemset = tuple(sorted(set(current_keys[i]) | set(current_keys[j])))

                if len(union_itemset) == k:
                    candidate_itemsets[union_itemset] = 0

        
        for index, transaction in df.iterrows():
            transaction_items = set(transaction['purchased_items'].split(','))
            for candidate in candidate_itemsets.keys():
                if set(candidate).issubset(transaction_items):
                    candidate_itemsets[candidate] += 1

        
        current_L = find_L(candidate_itemsets, min_sup)

        if len(current_L) > 0:
            all_frequent_itemsets[k] = current_L  

    return all_frequent_itemsets


def find_k_itemset(unique_items:list, min_sup:int):
    freq_itemsets = {}
    C1 = find_C_1(unique_items)
    L1 = find_L(C1, min_sup)
    C2 = find_C_2(L1, df)
    L2 = find_L(C2, min_sup)
    freq_itemsets[1] = L1
    freq_itemsets[2] = L2
    freq_itemsets.update(find_candidate_itemsets_after_L2(L2, df, min_sup))
    return freq_itemsets

L = find_k_itemset(unique_items, min_sup=10)
L
# Out:
# {1: {'CPU': 266,
#   'CPU Cooler': 244,
#   'Case': 245,
#   'Cooling Fan': 248,
#   'External HDD': 250,
#   'GPU': 238,
#   'Graphics Tablet': 228,
#   'HDD': 259,
#   'Headset': 247,
#   'Keyboard': 239,
#   'Monitor': 224,
#   'Motherboard': 258,
#   'Mouse': 255,
#   'Network Card': 239,
#   'Optical Drive': 250,
#   'Power Supply': 236,
#   'RAM': 234,
#   'RGB Lighting': 242,
#   'SSD': 247,
#   'Sound Card': 284,
#   'Speakers': 249,
#   'Surge Protector': 260,
#   'Thermal Paste': 253,
#   'UPS': 250,
#   'USB Hub': 248,
#   'Webcam': 229},
#  2: {('CPU', 'CPU Cooler'): 68,
#   ('CPU', 'Case'): 68,
#   ('CPU', 'Cooling Fan'): 67,
#   ('CPU', 'External HDD'): 65,
#   ('CPU', 'GPU'): 67,
#   ('CPU', 'Graphics Tablet'): 62,
#   ('CPU', 'HDD'): 57,
#   ('CPU', 'Headset'): 66,
#   ('CPU', 'Keyboard'): 71,
#   ('CPU', 'Monitor'): 70,
#   ('CPU', 'Motherboard'): 72,
#   ('CPU', 'Mouse'): 68,
#   ('CPU', 'Network Card'): 71,
#   ('CPU', 'Optical Drive'): 67,
#   ('CPU', 'Power Supply'): 65,
#   ('CPU', 'RAM'): 56,
#   ('CPU', 'RGB Lighting'): 79,
#   ('CPU', 'SSD'): 67,
#   ('CPU', 'Sound Card'): 84,
#   ('CPU', 'Speakers'): 72,
#   ('CPU', 'Surge Protector'): 69,
#   ('CPU', 'Thermal Paste'): 53,
#   ('CPU', 'UPS'): 62,
#   ('CPU', 'USB Hub'): 69,
#   ('CPU', 'Webcam'): 57,
#   ('CPU Cooler', 'Case'): 62,
#   ('CPU Cooler', 'Cooling Fan'): 61,
#   ('CPU Cooler', 'External HDD'): 66,
#   ('CPU Cooler', 'GPU'): 59,
#   ('CPU Cooler', 'Graphics Tablet'): 51,
#   ('CPU Cooler', 'HDD'): 59,
#   ('CPU Cooler', 'Headset'): 60,
#   ('CPU Cooler', 'Keyboard'): 58,
#   ('CPU Cooler', 'Monitor'): 57,
#   ('CPU Cooler', 'Motherboard'): 64,
#   ('CPU Cooler', 'Mouse'): 71,
#   ('CPU Cooler', 'Network Card'): 59,
#   ('CPU Cooler', 'Optical Drive'): 61,
#   ('CPU Cooler', 'Power Supply'): 49,
#   ('CPU Cooler', 'RAM'): 63,
#   ('CPU Cooler', 'RGB Lighting'): 56,
#   ('CPU Cooler', 'SSD'): 63,
#   ('CPU Cooler', 'Sound Card'): 70,
#   ('CPU Cooler', 'Speakers'): 59,
#   ('CPU Cooler', 'Surge Protector'): 67,
#   ('CPU Cooler', 'Thermal Paste'): 62,
#   ('CPU Cooler', 'UPS'): 55,
#   ('CPU Cooler', 'USB Hub'): 64,
#   ('CPU Cooler', 'Webcam'): 56,
#   ('Case', 'Cooling Fan'): 63,
#   ('Case', 'External HDD'): 56,
#   ('Case', 'GPU'): 56,
#   ('Case', 'Graphics Tablet'): 54,
#   ('Case', 'HDD'): 68,
#   ('Case', 'Headset'): 57,
#   ('Case', 'Keyboard'): 46,
#   ('Case', 'Monitor'): 61,
#   ('Case', 'Motherboard'): 52,
#   ('Case', 'Mouse'): 68,
#   ('Case', 'Network Card'): 58,
#   ('Case', 'Optical Drive'): 49,
#   ('Case', 'Power Supply'): 61,
#   ('Case', 'RAM'): 60,
#   ('Case', 'RGB Lighting'): 59,
#   ('Case', 'SSD'): 69,
#   ('Case', 'Sound Card'): 61,
#   ('Case', 'Speakers'): 57,
#   ('Case', 'Surge Protector'): 66,
#   ('Case', 'Thermal Paste'): 65,
#   ('Case', 'UPS'): 67,
#   ('Case', 'USB Hub'): 64,
#   ('Case', 'Webcam'): 59,
#   ('Cooling Fan', 'External HDD'): 68,
#   ('Cooling Fan', 'GPU'): 57,
#   ('Cooling Fan', 'Graphics Tablet'): 66,
#   ('Cooling Fan', 'HDD'): 75,
#   ('Cooling Fan', 'Headset'): 63,
#   ('Cooling Fan', 'Keyboard'): 50,
#   ('Cooling Fan', 'Monitor'): 63,
#   ('Cooling Fan', 'Motherboard'): 65,
#   ('Cooling Fan', 'Mouse'): 69,
#   ('Cooling Fan', 'Network Card'): 79,
#   ('Cooling Fan', 'Optical Drive'): 76,
#   ('Cooling Fan', 'Power Supply'): 61,
#   ('Cooling Fan', 'RAM'): 56,
#   ('Cooling Fan', 'RGB Lighting'): 66,
#   ('Cooling Fan', 'SSD'): 64,
#   ('Cooling Fan', 'Sound Card'): 67,
#   ('Cooling Fan', 'Speakers'): 57,
#   ('Cooling Fan', 'Surge Protector'): 72,
#   ('Cooling Fan', 'Thermal Paste'): 62,
#   ('Cooling Fan', 'UPS'): 49,
#   ('Cooling Fan', 'USB Hub'): 66,
#   ('Cooling Fan', 'Webcam'): 65,
#   ('External HDD', 'GPU'): 66,
#   ('External HDD', 'Graphics Tablet'): 53,
#   ('External HDD', 'HDD'): 71,
#   ('External HDD', 'Headset'): 74,
#   ('External HDD', 'Keyboard'): 64,
#   ('External HDD', 'Monitor'): 52,
#   ('External HDD', 'Motherboard'): 69,
#   ('External HDD', 'Mouse'): 64,
#   ('External HDD', 'Network Card'): 62,
#   ('External HDD', 'Optical Drive'): 66,
#   ('External HDD', 'Power Supply'): 64,
#   ('External HDD', 'RAM'): 62,
#   ('External HDD', 'RGB Lighting'): 60,
#   ('External HDD', 'SSD'): 64,
#   ('External HDD', 'Sound Card'): 58,
#   ('External HDD', 'Speakers'): 71,
#   ('External HDD', 'Surge Protector'): 66,
#   ('External HDD', 'Thermal Paste'): 71,
#   ('External HDD', 'UPS'): 67,
#   ('External HDD', 'USB Hub'): 61,
#   ('External HDD', 'Webcam'): 51,
#   ('GPU', 'Graphics Tablet'): 54,
#   ('GPU', 'HDD'): 58,
#   ('GPU', 'Headset'): 55,
#   ('GPU', 'Keyboard'): 53,
#   ('GPU', 'Monitor'): 58,
#   ('GPU', 'Motherboard'): 65,
#   ('GPU', 'Mouse'): 61,
#   ('GPU', 'Network Card'): 64,
#   ('GPU', 'Optical Drive'): 57,
#   ('GPU', 'Power Supply'): 56,
#   ('GPU', 'RAM'): 55,
#   ('GPU', 'RGB Lighting'): 53,
#   ('GPU', 'SSD'): 58,
#   ('GPU', 'Sound Card'): 82,
#   ('GPU', 'Speakers'): 71,
#   ('GPU', 'Surge Protector'): 64,
#   ('GPU', 'Thermal Paste'): 50,
#   ('GPU', 'UPS'): 66,
#   ('GPU', 'USB Hub'): 52,
#   ('GPU', 'Webcam'): 62,
#   ('Graphics Tablet', 'HDD'): 57,
#   ('Graphics Tablet', 'Headset'): 56,
#   ('Graphics Tablet', 'Keyboard'): 57,
#   ('Graphics Tablet', 'Monitor'): 49,
#   ('Graphics Tablet', 'Motherboard'): 68,
#   ('Graphics Tablet', 'Mouse'): 56,
#   ('Graphics Tablet', 'Network Card'): 53,
#   ('Graphics Tablet', 'Optical Drive'): 60,
#   ('Graphics Tablet', 'Power Supply'): 57,
#   ('Graphics Tablet', 'RAM'): 46,
#   ('Graphics Tablet', 'RGB Lighting'): 51,
#   ('Graphics Tablet', 'SSD'): 57,
#   ('Graphics Tablet', 'Sound Card'): 58,
#   ('Graphics Tablet', 'Speakers'): 55,
#   ('Graphics Tablet', 'Surge Protector'): 57,
#   ('Graphics Tablet', 'Thermal Paste'): 60,
#   ('Graphics Tablet', 'UPS'): 49,
#   ('Graphics Tablet', 'USB Hub'): 60,
#   ('Graphics Tablet', 'Webcam'): 63,
#   ('HDD', 'Headset'): 64,
#   ('HDD', 'Keyboard'): 55,
#   ('HDD', 'Monitor'): 49,
#   ('HDD', 'Motherboard'): 52,
#   ('HDD', 'Mouse'): 67,
#   ('HDD', 'Network Card'): 62,
#   ('HDD', 'Optical Drive'): 69,
#   ('HDD', 'Power Supply'): 54,
#   ('HDD', 'RAM'): 69,
#   ('HDD', 'RGB Lighting'): 70,
#   ('HDD', 'SSD'): 63,
#   ('HDD', 'Sound Card'): 73,
#   ('HDD', 'Speakers'): 59,
#   ('HDD', 'Surge Protector'): 71,
#   ('HDD', 'Thermal Paste'): 65,
#   ('HDD', 'UPS'): 65,
#   ('HDD', 'USB Hub'): 67,
#   ('HDD', 'Webcam'): 65,
#   ('Headset', 'Keyboard'): 70,
#   ('Headset', 'Monitor'): 47,
#   ('Headset', 'Motherboard'): 66,
#   ('Headset', 'Mouse'): 65,
#   ('Headset', 'Network Card'): 64,
#   ('Headset', 'Optical Drive'): 67,
#   ('Headset', 'Power Supply'): 58,
#   ('Headset', 'RAM'): 56,
#   ('Headset', 'RGB Lighting'): 66,
#   ('Headset', 'SSD'): 58,
#   ('Headset', 'Sound Card'): 65,
#   ('Headset', 'Speakers'): 62,
#   ('Headset', 'Surge Protector'): 58,
#   ('Headset', 'Thermal Paste'): 67,
#   ('Headset', 'UPS'): 74,
#   ('Headset', 'USB Hub'): 62,
#   ('Headset', 'Webcam'): 57,
#   ('Keyboard', 'Monitor'): 55,
#   ('Keyboard', 'Motherboard'): 61,
#   ('Keyboard', 'Mouse'): 62,
#   ('Keyboard', 'Network Card'): 58,
#   ('Keyboard', 'Optical Drive'): 64,
#   ('Keyboard', 'Power Supply'): 59,
#   ('Keyboard', 'RAM'): 62,
#   ('Keyboard', 'RGB Lighting'): 55,
#   ('Keyboard', 'SSD'): 60,
#   ('Keyboard', 'Sound Card'): 71,
#   ('Keyboard', 'Speakers'): 61,
#   ('Keyboard', 'Surge Protector'): 55,
#   ('Keyboard', 'Thermal Paste'): 61,
#   ('Keyboard', 'UPS'): 60,
#   ('Keyboard', 'USB Hub'): 64,
#   ('Keyboard', 'Webcam'): 60,
#   ('Monitor', 'Motherboard'): 61,
#   ('Monitor', 'Mouse'): 64,
#   ('Monitor', 'Network Card'): 54,
#   ('Monitor', 'Optical Drive'): 55,
#   ('Monitor', 'Power Supply'): 49,
#   ('Monitor', 'RAM'): 48,
#   ('Monitor', 'RGB Lighting'): 54,
#   ('Monitor', 'SSD'): 62,
#   ('Monitor', 'Sound Card'): 71,
#   ('Monitor', 'Speakers'): 60,
#   ('Monitor', 'Surge Protector'): 50,
#   ('Monitor', 'Thermal Paste'): 59,
#   ('Monitor', 'UPS'): 66,
#   ('Monitor', 'USB Hub'): 54,
#   ('Monitor', 'Webcam'): 51,
#   ('Motherboard', 'Mouse'): 72,
#   ('Motherboard', 'Network Card'): 57,
#   ('Motherboard', 'Optical Drive'): 64,
#   ('Motherboard', 'Power Supply'): 60,
#   ('Motherboard', 'RAM'): 60,
#   ('Motherboard', 'RGB Lighting'): 61,
#   ('Motherboard', 'SSD'): 67,
#   ('Motherboard', 'Sound Card'): 65,
#   ('Motherboard', 'Speakers'): 65,
#   ('Motherboard', 'Surge Protector'): 75,
#   ('Motherboard', 'Thermal Paste'): 74,
#   ('Motherboard', 'UPS'): 74,
#   ('Motherboard', 'USB Hub'): 69,
#   ('Motherboard', 'Webcam'): 65,
#   ('Mouse', 'Network Card'): 62,
#   ('Mouse', 'Optical Drive'): 60,
#   ('Mouse', 'Power Supply'): 66,
#   ('Mouse', 'RAM'): 58,
#   ('Mouse', 'RGB Lighting'): 70,
#   ('Mouse', 'SSD'): 68,
#   ('Mouse', 'Sound Card'): 69,
#   ('Mouse', 'Speakers'): 65,
#   ('Mouse', 'Surge Protector'): 70,
#   ('Mouse', 'Thermal Paste'): 70,
#   ('Mouse', 'UPS'): 68,
#   ('Mouse', 'USB Hub'): 65,
#   ('Mouse', 'Webcam'): 56,
#   ('Network Card', 'Optical Drive'): 52,
#   ('Network Card', 'Power Supply'): 51,
#   ('Network Card', 'RAM'): 54,
#   ('Network Card', 'RGB Lighting'): 57,
#   ('Network Card', 'SSD'): 55,
#   ('Network Card', 'Sound Card'): 73,
#   ('Network Card', 'Speakers'): 55,
#   ('Network Card', 'Surge Protector'): 63,
#   ('Network Card', 'Thermal Paste'): 55,
#   ('Network Card', 'UPS'): 63,
#   ('Network Card', 'USB Hub'): 53,
#   ('Network Card', 'Webcam'): 55,
#   ('Optical Drive', 'Power Supply'): 58,
#   ('Optical Drive', 'RAM'): 56,
#   ('Optical Drive', 'RGB Lighting'): 60,
#   ('Optical Drive', 'SSD'): 69,
#   ('Optical Drive', 'Sound Card'): 77,
#   ('Optical Drive', 'Speakers'): 62,
#   ('Optical Drive', 'Surge Protector'): 54,
#   ('Optical Drive', 'Thermal Paste'): 82,
#   ('Optical Drive', 'UPS'): 55,
#   ('Optical Drive', 'USB Hub'): 62,
#   ('Optical Drive', 'Webcam'): 71,
#   ('Power Supply', 'RAM'): 46,
#   ('Power Supply', 'RGB Lighting'): 62,
#   ('Power Supply', 'SSD'): 60,
#   ('Power Supply', 'Sound Card'): 65,
#   ('Power Supply', 'Speakers'): 58,
#   ('Power Supply', 'Surge Protector'): 61,
#   ('Power Supply', 'Thermal Paste'): 60,
#   ('Power Supply', 'UPS'): 70,
#   ('Power Supply', 'USB Hub'): 70,
#   ('Power Supply', 'Webcam'): 53,
#   ('RAM', 'RGB Lighting'): 64,
#   ('RAM', 'SSD'): 63,
#   ('RAM', 'Sound Card'): 64,
#   ('RAM', 'Speakers'): 59,
#   ('RAM', 'Surge Protector'): 68,
#   ('RAM', 'Thermal Paste'): 52,
#   ('RAM', 'UPS'): 63,
#   ('RAM', 'USB Hub'): 61,
#   ('RAM', 'Webcam'): 55,
#   ('RGB Lighting', 'SSD'): 62,
#   ('RGB Lighting', 'Sound Card'): 66,
#   ('RGB Lighting', 'Speakers'): 59,
#   ('RGB Lighting', 'Surge Protector'): 69,
#   ('RGB Lighting', 'Thermal Paste'): 63,
#   ('RGB Lighting', 'UPS'): 68,
#   ('RGB Lighting', 'USB Hub'): 62,
#   ('RGB Lighting', 'Webcam'): 56,
#   ('SSD', 'Sound Card'): 69,
#   ('SSD', 'Speakers'): 60,
#   ('SSD', 'Surge Protector'): 63,
#   ('SSD', 'Thermal Paste'): 64,
#   ('SSD', 'UPS'): 59,
#   ('SSD', 'USB Hub'): 75,
#   ('SSD', 'Webcam'): 61,
#   ('Sound Card', 'Speakers'): 71,
#   ('Sound Card', 'Surge Protector'): 58,
#   ('Sound Card', 'Thermal Paste'): 81,
#   ('Sound Card', 'UPS'): 79,
#   ('Sound Card', 'USB Hub'): 61,
#   ('Sound Card', 'Webcam'): 67,
#   ('Speakers', 'Surge Protector'): 61,
#   ('Speakers', 'Thermal Paste'): 62,
#   ('Speakers', 'UPS'): 63,
#   ('Speakers', 'USB Hub'): 65,
#   ('Speakers', 'Webcam'): 64,
#   ('Surge Protector', 'Thermal Paste'): 59,
#   ('Surge Protector', 'UPS'): 81,
#   ('Surge Protector', 'USB Hub'): 75,
#   ('Surge Protector', 'Webcam'): 74,
#   ('Thermal Paste', 'UPS'): 70,
#   ('Thermal Paste', 'USB Hub'): 59,
#   ('Thermal Paste', 'Webcam'): 59,
#   ('UPS', 'USB Hub'): 60,
#   ('UPS', 'Webcam'): 50,
#   ('USB Hub', 'Webcam'): 58},
#  3: {('CPU', 'CPU Cooler', 'Case'): 13,
#   ('CPU', 'CPU Cooler', 'Cooling Fan'): 21,
#   ('CPU', 'CPU Cooler', 'External HDD'): 21,
#   ('CPU', 'CPU Cooler', 'GPU'): 18,
#   ('CPU', 'CPU Cooler', 'Graphics Tablet'): 16,
#   ('CPU', 'CPU Cooler', 'HDD'): 15,
#   ('CPU', 'CPU Cooler', 'Headset'): 13,
#   ('CPU', 'CPU Cooler', 'Keyboard'): 16,
#   ('CPU', 'CPU Cooler', 'Monitor'): 15,
#   ('CPU', 'CPU Cooler', 'Motherboard'): 19,
#   ('CPU', 'CPU Cooler', 'Mouse'): 19,
#   ('CPU', 'CPU Cooler', 'Network Card'): 15,
#   ('CPU', 'CPU Cooler', 'Optical Drive'): 23,
#   ('CPU', 'CPU Cooler', 'Power Supply'): 13,
#   ('CPU', 'CPU Cooler', 'RAM'): 12,
#   ('CPU', 'CPU Cooler', 'RGB Lighting'): 19,
#   ('CPU', 'CPU Cooler', 'SSD'): 17,
#   ('CPU', 'CPU Cooler', 'Sound Card'): 21,
#   ('CPU', 'CPU Cooler', 'Speakers'): 17,
#   ('CPU', 'CPU Cooler', 'Surge Protector'): 17,
#   ('CPU', 'CPU Cooler', 'Thermal Paste'): 14,
#   ('CPU', 'CPU Cooler', 'UPS'): 13,
#   ('CPU', 'CPU Cooler', 'USB Hub'): 18,
#   ('CPU', 'CPU Cooler', 'Webcam'): 19,
#   ('CPU', 'Case', 'Cooling Fan'): 18,
#   ('CPU', 'Case', 'External HDD'): 16,
#   ('CPU', 'Case', 'GPU'): 16,
#   ('CPU', 'Case', 'Graphics Tablet'): 17,
#   ('CPU', 'Case', 'HDD'): 19,
#   ('CPU', 'Case', 'Headset'): 14,
#   ('CPU', 'Case', 'Keyboard'): 14,
#   ('CPU', 'Case', 'Monitor'): 13,
#   ('CPU', 'Case', 'Motherboard'): 18,
#   ('CPU', 'Case', 'Mouse'): 15,
#   ('CPU', 'Case', 'Network Card'): 17,
#   ('CPU', 'Case', 'Optical Drive'): 18,
#   ('CPU', 'Case', 'Power Supply'): 16,
#   ('CPU', 'Case', 'RAM'): 22,
#   ('CPU', 'Case', 'RGB Lighting'): 23,
#   ('CPU', 'Case', 'SSD'): 17,
#   ('CPU', 'Case', 'Sound Card'): 19,
#   ('CPU', 'Case', 'Speakers'): 16,
#   ('CPU', 'Case', 'Surge Protector'): 20,
#   ('CPU', 'Case', 'Thermal Paste'): 18,
#   ('CPU', 'Case', 'UPS'): 14,
#   ('CPU', 'Case', 'USB Hub'): 23,
#   ('CPU', 'Case', 'Webcam'): 11,
#   ('CPU', 'Cooling Fan', 'External HDD'): 17,
#   ('CPU', 'Cooling Fan', 'GPU'): 17,
#   ('CPU', 'Cooling Fan', 'Graphics Tablet'): 26,
#   ('CPU', 'Cooling Fan', 'HDD'): 13,
#   ('CPU', 'Cooling Fan', 'Headset'): 15,
#   ('CPU', 'Cooling Fan', 'Keyboard'): 17,
#   ('CPU', 'Cooling Fan', 'Monitor'): 25,
#   ('CPU', 'Cooling Fan', 'Motherboard'): 27,
#   ('CPU', 'Cooling Fan', 'Mouse'): 21,
#   ('CPU', 'Cooling Fan', 'Network Card'): 21,
#   ('CPU', 'Cooling Fan', 'Optical Drive'): 23,
#   ('CPU', 'Cooling Fan', 'Power Supply'): 16,
#   ('CPU', 'Cooling Fan', 'RAM'): 14,
#   ('CPU', 'Cooling Fan', 'RGB Lighting'): 22,
#   ('CPU', 'Cooling Fan', 'SSD'): 17,
#   ('CPU', 'Cooling Fan', 'Sound Card'): 21,
#   ('CPU', 'Cooling Fan', 'Speakers'): 14,
#   ('CPU', 'Cooling Fan', 'Surge Protector'): 20,
#   ('CPU', 'Cooling Fan', 'Thermal Paste'): 14,
#   ('CPU', 'Cooling Fan', 'UPS'): 12,
#   ('CPU', 'Cooling Fan', 'USB Hub'): 13,
#   ('CPU', 'Cooling Fan', 'Webcam'): 16,
#   ('CPU', 'External HDD', 'Graphics Tablet'): 14,
#   ('CPU', 'External HDD', 'HDD'): 13,
#   ('CPU', 'External HDD', 'Headset'): 18,
#   ('CPU', 'External HDD', 'Keyboard'): 21,
#   ('CPU', 'External HDD', 'Monitor'): 15,
#   ('CPU', 'External HDD', 'Motherboard'): 17,
#   ('CPU', 'External HDD', 'Mouse'): 21,
#   ('CPU', 'External HDD', 'Network Card'): 13,
#   ('CPU', 'External HDD', 'Optical Drive'): 18,
#   ('CPU', 'External HDD', 'Power Supply'): 15,
#   ('CPU', 'External HDD', 'RAM'): 14,
#   ('CPU', 'External HDD', 'RGB Lighting'): 23,
#   ('CPU', 'External HDD', 'SSD'): 14,
#   ('CPU', 'External HDD', 'Sound Card'): 16,
#   ('CPU', 'External HDD', 'Speakers'): 19,
#   ('CPU', 'External HDD', 'Surge Protector'): 19,
#   ('CPU', 'External HDD', 'Thermal Paste'): 13,
#   ('CPU', 'External HDD', 'UPS'): 17,
#   ('CPU', 'External HDD', 'USB Hub'): 25,
#   ('CPU', 'External HDD', 'Webcam'): 10,
#   ('CPU', 'GPU', 'Graphics Tablet'): 19,
#   ('CPU', 'GPU', 'HDD'): 17,
#   ('CPU', 'GPU', 'Headset'): 14,
#   ('CPU', 'GPU', 'Keyboard'): 20,
#   ('CPU', 'GPU', 'Monitor'): 19,
#   ('CPU', 'GPU', 'Motherboard'): 22,
#   ('CPU', 'GPU', 'Mouse'): 19,
#   ('CPU', 'GPU', 'Network Card'): 24,
#   ('CPU', 'GPU', 'Optical Drive'): 15,
#   ('CPU', 'GPU', 'Power Supply'): 18,
#   ('CPU', 'GPU', 'RAM'): 13,
#   ('CPU', 'GPU', 'RGB Lighting'): 13,
#   ('CPU', 'GPU', 'SSD'): 16,
#   ('CPU', 'GPU', 'Sound Card'): 24,
#   ('CPU', 'GPU', 'Speakers'): 22,
#   ('CPU', 'GPU', 'Surge Protector'): 16,
#   ('CPU', 'GPU', 'Thermal Paste'): 17,
#   ('CPU', 'GPU', 'UPS'): 14,
#   ('CPU', 'GPU', 'USB Hub'): 17,
#   ('CPU', 'GPU', 'Webcam'): 18,
#   ('CPU', 'Graphics Tablet', 'HDD'): 10,
#   ('CPU', 'Graphics Tablet', 'Headset'): 12,
#   ('CPU', 'Graphics Tablet', 'Keyboard'): 14,
#   ('CPU', 'Graphics Tablet', 'Monitor'): 21,
#   ('CPU', 'Graphics Tablet', 'Motherboard'): 19,
#   ('CPU', 'Graphics Tablet', 'Mouse'): 19,
#   ('CPU', 'Graphics Tablet', 'Network Card'): 16,
#   ('CPU', 'Graphics Tablet', 'Optical Drive'): 18,
#   ('CPU', 'Graphics Tablet', 'Power Supply'): 17,
#   ('CPU', 'Graphics Tablet', 'RAM'): 10,
#   ('CPU', 'Graphics Tablet', 'RGB Lighting'): 17,
#   ('CPU', 'Graphics Tablet', 'SSD'): 16,
#   ('CPU', 'Graphics Tablet', 'Sound Card'): 18,
#   ('CPU', 'Graphics Tablet', 'Speakers'): 15,
#   ('CPU', 'Graphics Tablet', 'Surge Protector'): 12,
#   ('CPU', 'Graphics Tablet', 'Thermal Paste'): 12,
#   ('CPU', 'Graphics Tablet', 'USB Hub'): 15,
#   ('CPU', 'Graphics Tablet', 'Webcam'): 15,
#   ('CPU', 'HDD', 'Headset'): 21,
#   ('CPU', 'HDD', 'Keyboard'): 13,
#   ('CPU', 'HDD', 'Monitor'): 14,
#   ('CPU', 'HDD', 'Motherboard'): 10,
#   ('CPU', 'HDD', 'Mouse'): 18,
#   ('CPU', 'HDD', 'Network Card'): 12,
#   ('CPU', 'HDD', 'Optical Drive'): 15,
#   ('CPU', 'HDD', 'Power Supply'): 11,
#   ('CPU', 'HDD', 'RAM'): 16,
#   ('CPU', 'HDD', 'RGB Lighting'): 18,
#   ('CPU', 'HDD', 'SSD'): 14,
#   ('CPU', 'HDD', 'Sound Card'): 20,
#   ('CPU', 'HDD', 'Speakers'): 17,
#   ('CPU', 'HDD', 'Surge Protector'): 15,
#   ('CPU', 'HDD', 'Thermal Paste'): 14,
#   ('CPU', 'HDD', 'UPS'): 17,
#   ('CPU', 'HDD', 'USB Hub'): 14,
#   ('CPU', 'HDD', 'Webcam'): 16,
#   ('CPU', 'Headset', 'Keyboard'): 20,
#   ('CPU', 'Headset', 'Monitor'): 16,
#   ('CPU', 'Headset', 'Motherboard'): 15,
#   ('CPU', 'Headset', 'Mouse'): 18,
#   ('CPU', 'Headset', 'Network Card'): 23,
#   ('CPU', 'Headset', 'Optical Drive'): 15,
#   ('CPU', 'Headset', 'Power Supply'): 13,
#   ('CPU', 'Headset', 'RGB Lighting'): 24,
#   ('CPU', 'Headset', 'SSD'): 18,
#   ('CPU', 'Headset', 'Sound Card'): 24,
#   ('CPU', 'Headset', 'Speakers'): 16,
#   ('CPU', 'Headset', 'Surge Protector'): 17,
#   ('CPU', 'Headset', 'Thermal Paste'): 11,
#   ('CPU', 'Headset', 'UPS'): 24,
#   ('CPU', 'Headset', 'USB Hub'): 17,
#   ('CPU', 'Headset', 'Webcam'): 15,
#   ('CPU', 'Keyboard', 'Monitor'): 18,
#   ('CPU', 'Keyboard', 'Motherboard'): 18,
#   ('CPU', 'Keyboard', 'Mouse'): 20,
#   ('CPU', 'Keyboard', 'Network Card'): 17,
#   ('CPU', 'Keyboard', 'Optical Drive'): 14,
#   ('CPU', 'Keyboard', 'Power Supply'): 24,
#   ('CPU', 'Keyboard', 'RAM'): 18,
#   ('CPU', 'Keyboard', 'RGB Lighting'): 22,
#   ('CPU', 'Keyboard', 'SSD'): 16,
#   ('CPU', 'Keyboard', 'Sound Card'): 25,
#   ('CPU', 'Keyboard', 'Speakers'): 19,
#   ('CPU', 'Keyboard', 'Surge Protector'): 17,
#   ('CPU', 'Keyboard', 'Thermal Paste'): 13,
#   ('CPU', 'Keyboard', 'UPS'): 16,
#   ('CPU', 'Keyboard', 'USB Hub'): 21,
#   ('CPU', 'Keyboard', 'Webcam'): 21,
#   ('CPU', 'Monitor', 'Motherboard'): 21,
#   ('CPU', 'Monitor', 'Mouse'): 21,
#   ('CPU', 'Monitor', 'Network Card'): 20,
#   ('CPU', 'Monitor', 'Optical Drive'): 20,
#   ('CPU', 'Monitor', 'Power Supply'): 16,
#   ('CPU', 'Monitor', 'RAM'): 15,
#   ('CPU', 'Monitor', 'RGB Lighting'): 14,
#   ('CPU', 'Monitor', 'SSD'): 21,
#   ('CPU', 'Monitor', 'Sound Card'): 22,
#   ('CPU', 'Monitor', 'Speakers'): 20,
#   ('CPU', 'Monitor', 'Surge Protector'): 13,
#   ('CPU', 'Monitor', 'Thermal Paste'): 11,
#   ('CPU', 'Monitor', 'UPS'): 18,
#   ('CPU', 'Monitor', 'USB Hub'): 19,
#   ('CPU', 'Monitor', 'Webcam'): 13,
#   ('CPU', 'Motherboard', 'Mouse'): 18,
#   ('CPU', 'Motherboard', 'Network Card'): 20,
#   ('CPU', 'Motherboard', 'Optical Drive'): 18,
#   ('CPU', 'Motherboard', 'Power Supply'): 21,
#   ('CPU', 'Motherboard', 'RAM'): 16,
#   ('CPU', 'Motherboard', 'RGB Lighting'): 23,
#   ('CPU', 'Motherboard', 'SSD'): 18,
#   ('CPU', 'Motherboard', 'Sound Card'): 19,
#   ('CPU', 'Motherboard', 'Speakers'): 21,
#   ('CPU', 'Motherboard', 'Surge Protector'): 21,
#   ('CPU', 'Motherboard', 'Thermal Paste'): 14,
#   ('CPU', 'Motherboard', 'UPS'): 16,
#   ('CPU', 'Motherboard', 'USB Hub'): 19,
#   ('CPU', 'Motherboard', 'Webcam'): 16,
#   ('CPU', 'Mouse', 'Network Card'): 15,
#   ('CPU', 'Mouse', 'Optical Drive'): 15,
#   ('CPU', 'Mouse', 'Power Supply'): 15,
#   ('CPU', 'Mouse', 'RAM'): 12,
#   ('CPU', 'Mouse', 'RGB Lighting'): 20,
#   ('CPU', 'Mouse', 'SSD'): 18,
#   ('CPU', 'Mouse', 'Sound Card'): 22,
#   ('CPU', 'Mouse', 'Speakers'): 17,
#   ('CPU', 'Mouse', 'Surge Protector'): 17,
#   ('CPU', 'Mouse', 'Thermal Paste'): 18,
#   ('CPU', 'Mouse', 'UPS'): 16,
#   ('CPU', 'Mouse', 'USB Hub'): 22,
#   ('CPU', 'Mouse', 'Webcam'): 20,
#   ('CPU', 'Network Card', 'Optical Drive'): 12,
#   ('CPU', 'Network Card', 'Power Supply'): 16,
#   ('CPU', 'Network Card', 'RGB Lighting'): 22,
#   ('CPU', 'Network Card', 'SSD'): 15,
#   ('CPU', 'Network Card', 'Sound Card'): 28,
#   ('CPU', 'Network Card', 'Speakers'): 18,
#   ('CPU', 'Network Card', 'Surge Protector'): 18,
#   ('CPU', 'Network Card', 'Thermal Paste'): 15,
#   ('CPU', 'Network Card', 'UPS'): 16,
#   ('CPU', 'Network Card', 'USB Hub'): 15,
#   ('CPU', 'Network Card', 'Webcam'): 12,
#   ('CPU', 'Optical Drive', 'Power Supply'): 18,
#   ('CPU', 'Optical Drive', 'RAM'): 18,
#   ('CPU', 'Optical Drive', 'RGB Lighting'): 19,
#   ('CPU', 'Optical Drive', 'SSD'): 23,
#   ('CPU', 'Optical Drive', 'Sound Card'): 26,
#   ('CPU', 'Optical Drive', 'Speakers'): 17,
#   ('CPU', 'Optical Drive', 'Surge Protector'): 16,
#   ('CPU', 'Optical Drive', 'Thermal Paste'): 13,
#   ('CPU', 'Optical Drive', 'UPS'): 18,
#   ('CPU', 'Optical Drive', 'USB Hub'): 15,
#   ('CPU', 'Optical Drive', 'Webcam'): 16,
#   ('CPU', 'Power Supply', 'RAM'): 13,
#   ('CPU', 'Power Supply', 'RGB Lighting'): 24,
#   ('CPU', 'Power Supply', 'SSD'): 13,
#   ('CPU', 'Power Supply', 'Sound Card'): 20,
#   ('CPU', 'Power Supply', 'Speakers'): 17,
#   ('CPU', 'Power Supply', 'Surge Protector'): 19,
#   ('CPU', 'Power Supply', 'Thermal Paste'): 15,
#   ('CPU', 'Power Supply', 'UPS'): 16,
#   ('CPU', 'Power Supply', 'USB Hub'): 18,
#   ('CPU', 'Power Supply', 'Webcam'): 12,
#   ('CPU', 'RAM', 'RGB Lighting'): 14,
#   ('CPU', 'RAM', 'SSD'): 16,
#   ('CPU', 'RAM', 'Sound Card'): 19,
#   ('CPU', 'RAM', 'Speakers'): 15,
#   ('CPU', 'RAM', 'Surge Protector'): 18,
#   ('CPU', 'RAM', 'UPS'): 12,
#   ('CPU', 'RAM', 'USB Hub'): 18,
#   ('CPU', 'RAM', 'Webcam'): 12,
#   ('CPU', 'RGB Lighting', 'SSD'): 18,
#   ('CPU', 'RGB Lighting', 'Sound Card'): 26,
#   ('CPU', 'RGB Lighting', 'Speakers'): 18,
#   ('CPU', 'RGB Lighting', 'Surge Protector'): 19,
#   ('CPU', 'RGB Lighting', 'Thermal Paste'): 14,
#   ('CPU', 'RGB Lighting', 'UPS'): 20,
#   ('CPU', 'RGB Lighting', 'USB Hub'): 22,
#   ('CPU', 'RGB Lighting', 'Webcam'): 17,
#   ('CPU', 'SSD', 'Sound Card'): 16,
#   ('CPU', 'SSD', 'Speakers'): 18,
#   ('CPU', 'SSD', 'Surge Protector'): 16,
#   ('CPU', 'SSD', 'Thermal Paste'): 10,
#   ('CPU', 'SSD', 'UPS'): 13,
#   ('CPU', 'SSD', 'USB Hub'): 22,
#   ('CPU', 'SSD', 'Webcam'): 12,
#   ('CPU', 'Sound Card', 'Speakers'): 19,
#   ('CPU', 'Sound Card', 'Surge Protector'): 18,
#   ('CPU', 'Sound Card', 'Thermal Paste'): 21,
#   ('CPU', 'Sound Card', 'UPS'): 23,
#   ('CPU', 'Sound Card', 'USB Hub'): 15,
#   ('CPU', 'Sound Card', 'Webcam'): 20,
#   ('CPU', 'Speakers', 'Surge Protector'): 19,
#   ('CPU', 'Speakers', 'Thermal Paste'): 15,
#   ('CPU', 'Speakers', 'UPS'): 16,
#   ('CPU', 'Speakers', 'USB Hub'): 19,
#   ('CPU', 'Speakers', 'Webcam'): 16,
#   ('CPU', 'Surge Protector', 'Thermal Paste'): 11,
#   ('CPU', 'Surge Protector', 'UPS'): 18,
#   ('CPU', 'Surge Protector', 'USB Hub'): 21,
#   ('CPU', 'Surge Protector', 'Webcam'): 15,
#   ('CPU', 'Thermal Paste', 'UPS'): 12,
#   ('CPU', 'Thermal Paste', 'USB Hub'): 11,
#   ('CPU', 'UPS', 'USB Hub'): 16,
#   ('CPU', 'UPS', 'Webcam'): 13,
#   ('CPU', 'USB Hub', 'Webcam'): 12,
#   ('CPU Cooler', 'Case', 'Cooling Fan'): 16,
#   ('CPU Cooler', 'Case', 'External HDD'): 19,
#   ('CPU Cooler', 'Case', 'GPU'): 15,
#   ('CPU Cooler', 'Case', 'Graphics Tablet'): 16,
#   ('CPU Cooler', 'Case', 'HDD'): 19,
#   ('CPU Cooler', 'Case', 'Headset'): 15,
#   ('CPU Cooler', 'Case', 'Keyboard'): 10,
#   ('CPU Cooler', 'Case', 'Monitor'): 11,
#   ('CPU Cooler', 'Case', 'Mouse'): 19,
#   ('CPU Cooler', 'Case', 'Network Card'): 15,
#   ('CPU Cooler', 'Case', 'Optical Drive'): 14,
#   ('CPU Cooler', 'Case', 'Power Supply'): 12,
#   ('CPU Cooler', 'Case', 'RAM'): 15,
#   ('CPU Cooler', 'Case', 'RGB Lighting'): 15,
#   ('CPU Cooler', 'Case', 'SSD'): 19,
#   ('CPU Cooler', 'Case', 'Sound Card'): 16,
#   ('CPU Cooler', 'Case', 'Speakers'): 16,
#   ('CPU Cooler', 'Case', 'Surge Protector'): 16,
#   ('CPU Cooler', 'Case', 'Thermal Paste'): 18,
#   ('CPU Cooler', 'Case', 'UPS'): 16,
#   ('CPU Cooler', 'Case', 'USB Hub'): 16,
#   ('CPU Cooler', 'Case', 'Webcam'): 15,
#   ('CPU Cooler', 'Cooling Fan', 'External HDD'): 22,
#   ('CPU Cooler', 'Cooling Fan', 'GPU'): 11,
#   ('CPU Cooler', 'Cooling Fan', 'Graphics Tablet'): 16,
#   ('CPU Cooler', 'Cooling Fan', 'HDD'): 19,
#   ('CPU Cooler', 'Cooling Fan', 'Headset'): 17,
#   ('CPU Cooler', 'Cooling Fan', 'Keyboard'): 10,
#   ('CPU Cooler', 'Cooling Fan', 'Monitor'): 19,
#   ('CPU Cooler', 'Cooling Fan', 'Motherboard'): 14,
#   ('CPU Cooler', 'Cooling Fan', 'Mouse'): 15,
#   ('CPU Cooler', 'Cooling Fan', 'Network Card'): 14,
#   ('CPU Cooler', 'Cooling Fan', 'Optical Drive'): 21,
#   ('CPU Cooler', 'Cooling Fan', 'Power Supply'): 11,
#   ('CPU Cooler', 'Cooling Fan', 'RAM'): 18,
#   ('CPU Cooler', 'Cooling Fan', 'RGB Lighting'): 15,
#   ('CPU Cooler', 'Cooling Fan', 'SSD'): 14,
#   ('CPU Cooler', 'Cooling Fan', 'Sound Card'): 14,
#   ('CPU Cooler', 'Cooling Fan', 'Speakers'): 12,
#   ('CPU Cooler', 'Cooling Fan', 'Surge Protector'): 22,
#   ('CPU Cooler', 'Cooling Fan', 'Thermal Paste'): 11,
#   ('CPU Cooler', 'Cooling Fan', 'UPS'): 10,
#   ('CPU Cooler', 'Cooling Fan', 'USB Hub'): 19,
#   ('CPU Cooler', 'Cooling Fan', 'Webcam'): 15,
#   ('CPU Cooler', 'External HDD', 'GPU'): 17,
#   ('CPU Cooler', 'External HDD', 'HDD'): 18,
#   ('CPU Cooler', 'External HDD', 'Headset'): 22,
#   ('CPU Cooler', 'External HDD', 'Keyboard'): 17,
#   ('CPU Cooler', 'External HDD', 'Monitor'): 13,
#   ('CPU Cooler', 'External HDD', 'Motherboard'): 19,
#   ('CPU Cooler', 'External HDD', 'Mouse'): 17,
#   ('CPU Cooler', 'External HDD', 'Network Card'): 14,
#   ('CPU Cooler', 'External HDD', 'Optical Drive'): 17,
#   ('CPU Cooler', 'External HDD', 'Power Supply'): 15,
#   ('CPU Cooler', 'External HDD', 'RAM'): 18,
#   ('CPU Cooler', 'External HDD', 'RGB Lighting'): 19,
#   ('CPU Cooler', 'External HDD', 'SSD'): 19,
#   ('CPU Cooler', 'External HDD', 'Sound Card'): 15,
#   ('CPU Cooler', 'External HDD', 'Speakers'): 18,
#   ('CPU Cooler', 'External HDD', 'Surge Protector'): 14,
#   ('CPU Cooler', 'External HDD', 'Thermal Paste'): 16,
#   ('CPU Cooler', 'External HDD', 'UPS'): 15,
#   ('CPU Cooler', 'External HDD', 'USB Hub'): 16,
#   ('CPU Cooler', 'GPU', 'Graphics Tablet'): 11,
#   ('CPU Cooler', 'GPU', 'HDD'): 10,
#   ('CPU Cooler', 'GPU', 'Headset'): 12,
#   ('CPU Cooler', 'GPU', 'Keyboard'): 16,
#   ('CPU Cooler', 'GPU', 'Monitor'): 18,
#   ('CPU Cooler', 'GPU', 'Motherboard'): 20,
#   ('CPU Cooler', 'GPU', 'Mouse'): 17,
#   ('CPU Cooler', 'GPU', 'Network Card'): 10,
#   ('CPU Cooler', 'GPU', 'Optical Drive'): 13,
#   ('CPU Cooler', 'GPU', 'Power Supply'): 10,
#   ('CPU Cooler', 'GPU', 'RAM'): 20,
#   ('CPU Cooler', 'GPU', 'RGB Lighting'): 11,
#   ('CPU Cooler', 'GPU', 'SSD'): 15,
#   ('CPU Cooler', 'GPU', 'Sound Card'): 20,
#   ('CPU Cooler', 'GPU', 'Speakers'): 16,
#   ('CPU Cooler', 'GPU', 'Surge Protector'): 15,
#   ('CPU Cooler', 'GPU', 'Thermal Paste'): 10,
#   ('CPU Cooler', 'GPU', 'UPS'): 11,
#   ('CPU Cooler', 'GPU', 'USB Hub'): 19,
#   ('CPU Cooler', 'GPU', 'Webcam'): 17,
#   ('CPU Cooler', 'Graphics Tablet', 'HDD'): 13,
#   ('CPU Cooler', 'Graphics Tablet', 'Headset'): 10,
#   ('CPU Cooler', 'Graphics Tablet', 'Keyboard'): 12,
#   ('CPU Cooler', 'Graphics Tablet', 'Motherboard'): 12,
#   ('CPU Cooler', 'Graphics Tablet', 'Mouse'): 15,
#   ('CPU Cooler', 'Graphics Tablet', 'Network Card'): 13,
#   ('CPU Cooler', 'Graphics Tablet', 'Optical Drive'): 14,
#   ('CPU Cooler', 'Graphics Tablet', 'Power Supply'): 14,
#   ('CPU Cooler', 'Graphics Tablet', 'RAM'): 14,
#   ('CPU Cooler', 'Graphics Tablet', 'RGB Lighting'): 10,
#   ('CPU Cooler', 'Graphics Tablet', 'SSD'): 15,
#   ('CPU Cooler', 'Graphics Tablet', 'Sound Card'): 15,
#   ('CPU Cooler', 'Graphics Tablet', 'Speakers'): 10,
#   ('CPU Cooler', 'Graphics Tablet', 'Surge Protector'): 13,
#   ('CPU Cooler', 'Graphics Tablet', 'Thermal Paste'): 13,
#   ('CPU Cooler', 'Graphics Tablet', 'USB Hub'): 12,
#   ('CPU Cooler', 'Graphics Tablet', 'Webcam'): 14,
#   ('CPU Cooler', 'HDD', 'Headset'): 15,
#   ('CPU Cooler', 'HDD', 'Monitor'): 13,
#   ('CPU Cooler', 'HDD', 'Motherboard'): 14,
#   ('CPU Cooler', 'HDD', 'Mouse'): 15,
#   ('CPU Cooler', 'HDD', 'Network Card'): 12,
#   ('CPU Cooler', 'HDD', 'Optical Drive'): 17,
#   ('CPU Cooler', 'HDD', 'RAM'): 12,
#   ('CPU Cooler', 'HDD', 'RGB Lighting'): 15,
#   ('CPU Cooler', 'HDD', 'SSD'): 15,
#   ('CPU Cooler', 'HDD', 'Sound Card'): 19,
#   ('CPU Cooler', 'HDD', 'Speakers'): 12,
#   ('CPU Cooler', 'HDD', 'Surge Protector'): 10,
#   ('CPU Cooler', 'HDD', 'Thermal Paste'): 16,
#   ('CPU Cooler', 'HDD', 'UPS'): 14,
#   ('CPU Cooler', 'HDD', 'USB Hub'): 15,
#   ('CPU Cooler', 'HDD', 'Webcam'): 13,
#   ('CPU Cooler', 'Headset', 'Keyboard'): 18,
#   ('CPU Cooler', 'Headset', 'Motherboard'): 20,
#   ('CPU Cooler', 'Headset', 'Mouse'): 19,
#   ('CPU Cooler', 'Headset', 'Network Card'): 15,
#   ('CPU Cooler', 'Headset', 'Optical Drive'): 16,
#   ('CPU Cooler', 'Headset', 'Power Supply'): 11,
#   ('CPU Cooler', 'Headset', 'RAM'): 19,
#   ('CPU Cooler', 'Headset', 'RGB Lighting'): 12,
#   ('CPU Cooler', 'Headset', 'SSD'): 18,
#   ('CPU Cooler', 'Headset', 'Sound Card'): 12,
#   ('CPU Cooler', 'Headset', 'Speakers'): 18,
#   ('CPU Cooler', 'Headset', 'Surge Protector'): 15,
#   ('CPU Cooler', 'Headset', 'Thermal Paste'): 15,
#   ('CPU Cooler', 'Headset', 'UPS'): 12,
#   ('CPU Cooler', 'Headset', 'USB Hub'): 15,
#   ('CPU Cooler', 'Keyboard', 'Monitor'): 12,
#   ('CPU Cooler', 'Keyboard', 'Motherboard'): 13,
#   ('CPU Cooler', 'Keyboard', 'Mouse'): 16,
#   ('CPU Cooler', 'Keyboard', 'Network Card'): 13,
#   ('CPU Cooler', 'Keyboard', 'Optical Drive'): 16,
#   ('CPU Cooler', 'Keyboard', 'Power Supply'): 11,
#   ('CPU Cooler', 'Keyboard', 'RAM'): 17,
#   ('CPU Cooler', 'Keyboard', 'RGB Lighting'): 15,
#   ('CPU Cooler', 'Keyboard', 'SSD'): 16,
#   ('CPU Cooler', 'Keyboard', 'Sound Card'): 22,
#   ('CPU Cooler', 'Keyboard', 'Speakers'): 15,
#   ('CPU Cooler', 'Keyboard', 'Surge Protector'): 12,
#   ('CPU Cooler', 'Keyboard', 'Thermal Paste'): 15,
#   ('CPU Cooler', 'Keyboard', 'UPS'): 10,
#   ('CPU Cooler', 'Keyboard', 'USB Hub'): 13,
#   ('CPU Cooler', 'Keyboard', 'Webcam'): 10,
#   ('CPU Cooler', 'Monitor', 'Motherboard'): 17,
#   ('CPU Cooler', 'Monitor', 'Mouse'): 18,
#   ('CPU Cooler', 'Monitor', 'Network Card'): 12,
#   ('CPU Cooler', 'Monitor', 'Optical Drive'): 10,
#   ('CPU Cooler', 'Monitor', 'Power Supply'): 13,
#   ('CPU Cooler', 'Monitor', 'RAM'): 15,
#   ('CPU Cooler', 'Monitor', 'RGB Lighting'): 13,
#   ('CPU Cooler', 'Monitor', 'SSD'): 20,
#   ('CPU Cooler', 'Monitor', 'Sound Card'): 21,
#   ('CPU Cooler', 'Monitor', 'Speakers'): 16,
#   ('CPU Cooler', 'Monitor', 'Surge Protector'): 16,
#   ('CPU Cooler', 'Monitor', 'Thermal Paste'): 15,
#   ('CPU Cooler', 'Monitor', 'UPS'): 16,
#   ('CPU Cooler', 'Monitor', 'USB Hub'): 15,
#   ('CPU Cooler', 'Monitor', 'Webcam'): 11,
#   ('CPU Cooler', 'Motherboard', 'Mouse'): 22,
#   ('CPU Cooler', 'Motherboard', 'Network Card'): 14,
#   ('CPU Cooler', 'Motherboard', 'Optical Drive'): 19,
#   ('CPU Cooler', 'Motherboard', 'Power Supply'): 13,
#   ('CPU Cooler', 'Motherboard', 'RAM'): 19,
#   ('CPU Cooler', 'Motherboard', 'RGB Lighting'): 15,
#   ('CPU Cooler', 'Motherboard', 'SSD'): 16,
#   ('CPU Cooler', 'Motherboard', 'Sound Card'): 16,
#   ('CPU Cooler', 'Motherboard', 'Speakers'): 14,
#   ('CPU Cooler', 'Motherboard', 'Surge Protector'): 14,
#   ('CPU Cooler', 'Motherboard', 'Thermal Paste'): 17,
#   ('CPU Cooler', 'Motherboard', 'UPS'): 17,
#   ('CPU Cooler', 'Motherboard', 'USB Hub'): 16,
#   ('CPU Cooler', 'Motherboard', 'Webcam'): 12,
#   ('CPU Cooler', 'Mouse', 'Network Card'): 19,
#   ('CPU Cooler', 'Mouse', 'Optical Drive'): 12,
#   ('CPU Cooler', 'Mouse', 'Power Supply'): 15,
#   ('CPU Cooler', 'Mouse', 'RAM'): 16,
#   ('CPU Cooler', 'Mouse', 'RGB Lighting'): 21,
#   ('CPU Cooler', 'Mouse', 'SSD'): 24,
#   ('CPU Cooler', 'Mouse', 'Sound Card'): 16,
#   ('CPU Cooler', 'Mouse', 'Speakers'): 20,
#   ('CPU Cooler', 'Mouse', 'Surge Protector'): 21,
#   ('CPU Cooler', 'Mouse', 'Thermal Paste'): 19,
#   ('CPU Cooler', 'Mouse', 'UPS'): 13,
#   ('CPU Cooler', 'Mouse', 'USB Hub'): 24,
#   ('CPU Cooler', 'Mouse', 'Webcam'): 16,
#   ('CPU Cooler', 'Network Card', 'Optical Drive'): 13,
#   ('CPU Cooler', 'Network Card', 'Power Supply'): 13,
#   ('CPU Cooler', 'Network Card', 'RAM'): 20,
#   ('CPU Cooler', 'Network Card', 'RGB Lighting'): 16,
#   ('CPU Cooler', 'Network Card', 'SSD'): 14,
#   ('CPU Cooler', 'Network Card', 'Sound Card'): 21,
#   ('CPU Cooler', 'Network Card', 'Speakers'): 14,
#   ('CPU Cooler', 'Network Card', 'Surge Protector'): 17,
#   ('CPU Cooler', 'Network Card', 'Thermal Paste'): 12,
#   ('CPU Cooler', 'Network Card', 'UPS'): 18,
#   ('CPU Cooler', 'Network Card', 'USB Hub'): 11,
#   ('CPU Cooler', 'Network Card', 'Webcam'): 15,
#   ('CPU Cooler', 'Optical Drive', 'Power Supply'): 11,
#   ('CPU Cooler', 'Optical Drive', 'RAM'): 17,
#   ('CPU Cooler', 'Optical Drive', 'RGB Lighting'): 13,
#   ('CPU Cooler', 'Optical Drive', 'SSD'): 13,
#   ('CPU Cooler', 'Optical Drive', 'Sound Card'): 17,
#   ('CPU Cooler', 'Optical Drive', 'Speakers'): 14,
#   ('CPU Cooler', 'Optical Drive', 'Surge Protector'): 17,
#   ('CPU Cooler', 'Optical Drive', 'Thermal Paste'): 17,
#   ('CPU Cooler', 'Optical Drive', 'UPS'): 13,
#   ('CPU Cooler', 'Optical Drive', 'USB Hub'): 16,
#   ('CPU Cooler', 'Optical Drive', 'Webcam'): 17,
#   ('CPU Cooler', 'Power Supply', 'RAM'): 11,
#   ('CPU Cooler', 'Power Supply', 'RGB Lighting'): 12,
#   ('CPU Cooler', 'Power Supply', 'SSD'): 11,
#   ('CPU Cooler', 'Power Supply', 'Sound Card'): 14,
#   ('CPU Cooler', 'Power Supply', 'Speakers'): 10,
#   ('CPU Cooler', 'Power Supply', 'Surge Protector'): 14,
#   ('CPU Cooler', 'Power Supply', 'Thermal Paste'): 14,
#   ('CPU Cooler', 'Power Supply', 'UPS'): 16,
#   ('CPU Cooler', 'Power Supply', 'USB Hub'): 18,
#   ('CPU Cooler', 'Power Supply', 'Webcam'): 11,
#   ('CPU Cooler', 'RAM', 'RGB Lighting'): 17,
#   ('CPU Cooler', 'RAM', 'SSD'): 21,
#   ('CPU Cooler', 'RAM', 'Sound Card'): 15,
#   ('CPU Cooler', 'RAM', 'Speakers'): 16,
#   ('CPU Cooler', 'RAM', 'Surge Protector'): 15,
#   ('CPU Cooler', 'RAM', 'Thermal Paste'): 15,
#   ('CPU Cooler', 'RAM', 'UPS'): 19,
#   ('CPU Cooler', 'RAM', 'USB Hub'): 17,
#   ('CPU Cooler', 'RAM', 'Webcam'): 12,
#   ('CPU Cooler', 'RGB Lighting', 'SSD'): 12,
#   ('CPU Cooler', 'RGB Lighting', 'Sound Card'): 12,
#   ('CPU Cooler', 'RGB Lighting', 'Speakers'): 14,
#   ('CPU Cooler', 'RGB Lighting', 'Surge Protector'): 13,
#   ('CPU Cooler', 'RGB Lighting', 'Thermal Paste'): 12,
#   ('CPU Cooler', 'RGB Lighting', 'UPS'): 14,
#   ('CPU Cooler', 'RGB Lighting', 'USB Hub'): 15,
#   ('CPU Cooler', 'RGB Lighting', 'Webcam'): 12,
#   ('CPU Cooler', 'SSD', 'Sound Card'): 18,
#   ('CPU Cooler', 'SSD', 'Speakers'): 14,
#   ('CPU Cooler', 'SSD', 'Surge Protector'): 22,
#   ('CPU Cooler', 'SSD', 'Thermal Paste'): 17,
#   ('CPU Cooler', 'SSD', 'UPS'): 17,
#   ('CPU Cooler', 'SSD', 'USB Hub'): 22,
#   ('CPU Cooler', 'SSD', 'Webcam'): 13,
#   ('CPU Cooler', 'Sound Card', 'Speakers'): 20,
#   ('CPU Cooler', 'Sound Card', 'Surge Protector'): 12,
#   ('CPU Cooler', 'Sound Card', 'Thermal Paste'): 20,
#   ('CPU Cooler', 'Sound Card', 'UPS'): 14,
#   ('CPU Cooler', 'Sound Card', 'USB Hub'): 17,
#   ('CPU Cooler', 'Sound Card', 'Webcam'): 16,
#   ('CPU Cooler', 'Speakers', 'Surge Protector'): 11,
#   ('CPU Cooler', 'Speakers', 'Thermal Paste'): 19,
#   ('CPU Cooler', 'Speakers', 'UPS'): 15,
#   ('CPU Cooler', 'Speakers', 'USB Hub'): 19,
#   ('CPU Cooler', 'Speakers', 'Webcam'): 13,
#   ('CPU Cooler', 'Surge Protector', 'Thermal Paste'): 18,
#   ('CPU Cooler', 'Surge Protector', 'UPS'): 16,
#   ('CPU Cooler', 'Surge Protector', 'USB Hub'): 19,
#   ('CPU Cooler', 'Surge Protector', 'Webcam'): 22,
#   ('CPU Cooler', 'Thermal Paste', 'UPS'): 15,
#   ('CPU Cooler', 'Thermal Paste', 'USB Hub'): 17,
#   ('CPU Cooler', 'Thermal Paste', 'Webcam'): 13,
#   ('CPU Cooler', 'UPS', 'USB Hub'): 13,
#   ('CPU Cooler', 'UPS', 'Webcam'): 10,
#   ('CPU Cooler', 'USB Hub', 'Webcam'): 16,
#   ('Case', 'Cooling Fan', 'External HDD'): 16,
#   ('Case', 'Cooling Fan', 'Graphics Tablet'): 15,
#   ('Case', 'Cooling Fan', 'HDD'): 20,
#   ('Case', 'Cooling Fan', 'Headset'): 15,
#   ('Case', 'Cooling Fan', 'Monitor'): 22,
#   ('Case', 'Cooling Fan', 'Motherboard'): 14,
#   ('Case', 'Cooling Fan', 'Mouse'): 23,
#   ('Case', 'Cooling Fan', 'Network Card'): 21,
#   ('Case', 'Cooling Fan', 'Optical Drive'): 15,
#   ('Case', 'Cooling Fan', 'Power Supply'): 12,
#   ('Case', 'Cooling Fan', 'RAM'): 16,
#   ('Case', 'Cooling Fan', 'RGB Lighting'): 17,
#   ('Case', 'Cooling Fan', 'SSD'): 20,
#   ('Case', 'Cooling Fan', 'Sound Card'): 20,
#   ('Case', 'Cooling Fan', 'Speakers'): 14,
#   ('Case', 'Cooling Fan', 'Surge Protector'): 18,
#   ('Case', 'Cooling Fan', 'Thermal Paste'): 18,
#   ('Case', 'Cooling Fan', 'UPS'): 13,
#   ('Case', 'Cooling Fan', 'USB Hub'): 16,
#   ('Case', 'Cooling Fan', 'Webcam'): 16,
#   ('Case', 'External HDD', 'GPU'): 12,
#   ('Case', 'External HDD', 'Graphics Tablet'): 10,
#   ('Case', 'External HDD', 'HDD'): 18,
#   ('Case', 'External HDD', 'Headset'): 16,
#   ('Case', 'External HDD', 'Monitor'): 14,
#   ('Case', 'External HDD', 'Motherboard'): 15,
#   ('Case', 'External HDD', 'Mouse'): 19,
#   ('Case', 'External HDD', 'Network Card'): 12,
#   ('Case', 'External HDD', 'Optical Drive'): 12,
#   ('Case', 'External HDD', 'Power Supply'): 17,
#   ('Case', 'External HDD', 'RAM'): 15,
#   ('Case', 'External HDD', 'RGB Lighting'): 11,
#   ('Case', 'External HDD', 'SSD'): 13,
#   ('Case', 'External HDD', 'Speakers'): 15,
#   ('Case', 'External HDD', 'Surge Protector'): 19,
#   ('Case', 'External HDD', 'Thermal Paste'): 18,
#   ('Case', 'External HDD', 'UPS'): 20,
#   ('Case', 'External HDD', 'USB Hub'): 15,
#   ('Case', 'External HDD', 'Webcam'): 11,
#   ('Case', 'GPU', 'Graphics Tablet'): 11,
#   ('Case', 'GPU', 'HDD'): 13,
#   ('Case', 'GPU', 'Headset'): 11,
#   ('Case', 'GPU', 'Monitor'): 13,
#   ('Case', 'GPU', 'Motherboard'): 11,
#   ('Case', 'GPU', 'Mouse'): 21,
#   ('Case', 'GPU', 'Network Card'): 14,
#   ('Case', 'GPU', 'Optical Drive'): 10,
#   ('Case', 'GPU', 'Power Supply'): 16,
#   ('Case', 'GPU', 'SSD'): 11,
#   ('Case', 'GPU', 'Sound Card'): 20,
#   ('Case', 'GPU', 'Speakers'): 15,
#   ('Case', 'GPU', 'Surge Protector'): 13,
#   ('Case', 'GPU', 'Thermal Paste'): 13,
#   ('Case', 'GPU', 'UPS'): 17,
#   ('Case', 'GPU', 'USB Hub'): 17,
#   ('Case', 'GPU', 'Webcam'): 14,
#   ('Case', 'Graphics Tablet', 'HDD'): 14,
#   ('Case', 'Graphics Tablet', 'Keyboard'): 10,
#   ('Case', 'Graphics Tablet', 'Monitor'): 14,
#   ('Case', 'Graphics Tablet', 'Motherboard'): 15,
#   ('Case', 'Graphics Tablet', 'Mouse'): 17,
#   ('Case', 'Graphics Tablet', 'Network Card'): 13,
#   ('Case', 'Graphics Tablet', 'Optical Drive'): 14,
#   ('Case', 'Graphics Tablet', 'Power Supply'): 13,
#   ('Case', 'Graphics Tablet', 'RAM'): 17,
#   ('Case', 'Graphics Tablet', 'RGB Lighting'): 19,
#   ('Case', 'Graphics Tablet', 'SSD'): 22,
#   ('Case', 'Graphics Tablet', 'Sound Card'): 13,
#   ('Case', 'Graphics Tablet', 'Surge Protector'): 16,
#   ('Case', 'Graphics Tablet', 'Thermal Paste'): 20,
#   ('Case', 'Graphics Tablet', 'UPS'): 13,
#   ('Case', 'Graphics Tablet', 'USB Hub'): 13,
#   ('Case', 'Graphics Tablet', 'Webcam'): 17,
#   ('Case', 'HDD', 'Headset'): 14,
#   ('Case', 'HDD', 'Keyboard'): 12,
#   ('Case', 'HDD', 'Monitor'): 14,
#   ('Case', 'HDD', 'Motherboard'): 11,
#   ('Case', 'HDD', 'Mouse'): 16,
#   ('Case', 'HDD', 'Network Card'): 18,
#   ('Case', 'HDD', 'Optical Drive'): 17,
#   ('Case', 'HDD', 'Power Supply'): 15,
#   ('Case', 'HDD', 'RAM'): 20,
#   ('Case', 'HDD', 'RGB Lighting'): 17,
#   ('Case', 'HDD', 'SSD'): 19,
#   ('Case', 'HDD', 'Sound Card'): 12,
#   ('Case', 'HDD', 'Speakers'): 12,
#   ('Case', 'HDD', 'Surge Protector'): 26,
#   ('Case', 'HDD', 'Thermal Paste'): 19,
#   ('Case', 'HDD', 'UPS'): 17,
#   ('Case', 'HDD', 'USB Hub'): 17,
#   ('Case', 'HDD', 'Webcam'): 18,
#   ('Case', 'Headset', 'Keyboard'): 15,
#   ('Case', 'Headset', 'Monitor'): 12,
#   ('Case', 'Headset', 'Motherboard'): 12,
#   ('Case', 'Headset', 'Mouse'): 10,
#   ('Case', 'Headset', 'Network Card'): 14,
#   ('Case', 'Headset', 'Optical Drive'): 12,
#   ('Case', 'Headset', 'Power Supply'): 14,
#   ('Case', 'Headset', 'RAM'): 11,
#   ('Case', 'Headset', 'RGB Lighting'): 11,
#   ('Case', 'Headset', 'SSD'): 12,
#   ('Case', 'Headset', 'Sound Card'): 13,
#   ('Case', 'Headset', 'Speakers'): 13,
#   ('Case', 'Headset', 'Surge Protector'): 14,
#   ('Case', 'Headset', 'Thermal Paste'): 18,
#   ('Case', 'Headset', 'UPS'): 21,
#   ('Case', 'Headset', 'USB Hub'): 13,
#   ('Case', 'Headset', 'Webcam'): 12,
#   ('Case', 'Keyboard', 'Monitor'): 15,
#   ('Case', 'Keyboard', 'Motherboard'): 11,
#   ('Case', 'Keyboard', 'Power Supply'): 11,
#   ('Case', 'Keyboard', 'RAM'): 12,
#   ('Case', 'Keyboard', 'RGB Lighting'): 11,
#   ('Case', 'Keyboard', 'SSD'): 14,
#   ('Case', 'Keyboard', 'Sound Card'): 15,
#   ('Case', 'Keyboard', 'Speakers'): 10,
#   ('Case', 'Keyboard', 'Surge Protector'): 13,
#   ('Case', 'Keyboard', 'Thermal Paste'): 16,
#   ('Case', 'Keyboard', 'UPS'): 15,
#   ('Case', 'Keyboard', 'USB Hub'): 12,
#   ('Case', 'Keyboard', 'Webcam'): 12,
#   ('Case', 'Monitor', 'Motherboard'): 15,
#   ('Case', 'Monitor', 'Mouse'): 18,
#   ('Case', 'Monitor', 'Network Card'): 13,
#   ('Case', 'Monitor', 'Optical Drive'): 13,
#   ('Case', 'Monitor', 'Power Supply'): 12,
#   ('Case', 'Monitor', 'RAM'): 16,
#   ('Case', 'Monitor', 'RGB Lighting'): 16,
#   ('Case', 'Monitor', 'SSD'): 17,
#   ('Case', 'Monitor', 'Sound Card'): 23,
#   ('Case', 'Monitor', 'Speakers'): 17,
#   ('Case', 'Monitor', 'Surge Protector'): 14,
#   ('Case', 'Monitor', 'Thermal Paste'): 19,
#   ('Case', 'Monitor', 'UPS'): 18,
#   ('Case', 'Monitor', 'USB Hub'): 19,
#   ('Case', 'Monitor', 'Webcam'): 15,
#   ('Case', 'Motherboard', 'Mouse'): 15,
#   ('Case', 'Motherboard', 'Network Card'): 11,
#   ('Case', 'Motherboard', 'Power Supply'): 11,
#   ('Case', 'Motherboard', 'RAM'): 16,
#   ('Case', 'Motherboard', 'SSD'): 20,
#   ('Case', 'Motherboard', 'Speakers'): 14,
#   ('Case', 'Motherboard', 'Surge Protector'): 17,
#   ('Case', 'Motherboard', 'Thermal Paste'): 17,
#   ('Case', 'Motherboard', 'UPS'): 16,
#   ('Case', 'Motherboard', 'USB Hub'): 14,
#   ('Case', 'Motherboard', 'Webcam'): 19,
#   ('Case', 'Mouse', 'Network Card'): 17,
#   ('Case', 'Mouse', 'Optical Drive'): 11,
#   ('Case', 'Mouse', 'Power Supply'): 18,
#   ('Case', 'Mouse', 'RAM'): 15,
#   ('Case', 'Mouse', 'RGB Lighting'): 18,
#   ('Case', 'Mouse', 'SSD'): 22,
#   ('Case', 'Mouse', 'Sound Card'): 20,
#   ('Case', 'Mouse', 'Speakers'): 14,
#   ('Case', 'Mouse', 'Surge Protector'): 22,
#   ('Case', 'Mouse', 'Thermal Paste'): 17,
#   ('Case', 'Mouse', 'UPS'): 17,
#   ('Case', 'Mouse', 'USB Hub'): 15,
#   ('Case', 'Mouse', 'Webcam'): 19,
#   ('Case', 'Network Card', 'Optical Drive'): 10,
#   ('Case', 'Network Card', 'Power Supply'): 13,
#   ('Case', 'Network Card', 'RAM'): 15,
#   ('Case', 'Network Card', 'RGB Lighting'): 11,
#   ('Case', 'Network Card', 'SSD'): 15,
#   ('Case', 'Network Card', 'Sound Card'): 17,
#   ('Case', 'Network Card', 'Surge Protector'): 12,
#   ('Case', 'Network Card', 'Thermal Paste'): 10,
#   ('Case', 'Network Card', 'UPS'): 16,
#   ('Case', 'Network Card', 'USB Hub'): 14,
#   ('Case', 'Network Card', 'Webcam'): 12,
#   ('Case', 'Optical Drive', 'Power Supply'): 13,
#   ('Case', 'Optical Drive', 'RAM'): 10,
#   ('Case', 'Optical Drive', 'RGB Lighting'): 15,
#   ('Case', 'Optical Drive', 'SSD'): 19,
#   ('Case', 'Optical Drive', 'Sound Card'): 12,
#   ('Case', 'Optical Drive', 'Speakers'): 14,
#   ('Case', 'Optical Drive', 'Surge Protector'): 10,
#   ('Case', 'Optical Drive', 'Thermal Paste'): 18,
#   ('Case', 'Optical Drive', 'UPS'): 10,
#   ('Case', 'Optical Drive', 'USB Hub'): 16,
#   ('Case', 'Optical Drive', 'Webcam'): 14,
#   ('Case', 'Power Supply', 'RGB Lighting'): 16,
#   ('Case', 'Power Supply', 'SSD'): 10,
#   ('Case', 'Power Supply', 'Sound Card'): 15,
#   ('Case', 'Power Supply', 'Speakers'): 12,
#   ('Case', 'Power Supply', 'Surge Protector'): 17,
#   ('Case', 'Power Supply', 'Thermal Paste'): 15,
#   ('Case', 'Power Supply', 'UPS'): 20,
#   ('Case', 'Power Supply', 'USB Hub'): 15,
#   ('Case', 'Power Supply', 'Webcam'): 15,
#   ('Case', 'RAM', 'RGB Lighting'): 13,
#   ('Case', 'RAM', 'SSD'): 19,
#   ('Case', 'RAM', 'Sound Card'): 11,
#   ('Case', 'RAM', 'Speakers'): 13,
#   ('Case', 'RAM', 'Surge Protector'): 19,
#   ('Case', 'RAM', 'Thermal Paste'): 18,
#   ('Case', 'RAM', 'UPS'): 14,
#   ('Case', 'RAM', 'USB Hub'): 20,
#   ('Case', 'RAM', 'Webcam'): 15,
#   ('Case', 'RGB Lighting', 'SSD'): 19,
#   ('Case', 'RGB Lighting', 'Sound Card'): 14,
#   ('Case', 'RGB Lighting', 'Speakers'): 14,
#   ('Case', 'RGB Lighting', 'Surge Protector'): 17,
#   ('Case', 'RGB Lighting', 'Thermal Paste'): 15,
#   ('Case', 'RGB Lighting', 'UPS'): 13,
#   ('Case', 'RGB Lighting', 'USB Hub'): 15,
#   ('Case', 'RGB Lighting', 'Webcam'): 11,
#   ('Case', 'SSD', 'Sound Card'): 14,
#   ('Case', 'SSD', 'Speakers'): 19,
#   ('Case', 'SSD', 'Surge Protector'): 18,
#   ('Case', 'SSD', 'Thermal Paste'): 19,
#   ('Case', 'SSD', 'UPS'): 19,
#   ('Case', 'SSD', 'USB Hub'): 22,
#   ('Case', 'SSD', 'Webcam'): 18,
#   ('Case', 'Sound Card', 'Speakers'): 14,
#   ('Case', 'Sound Card', 'Surge Protector'): 11,
#   ('Case', 'Sound Card', 'Thermal Paste'): 18,
#   ('Case', 'Sound Card', 'UPS'): 16,
#   ('Case', 'Sound Card', 'USB Hub'): 15,
#   ('Case', 'Sound Card', 'Webcam'): 16,
#   ('Case', 'Speakers', 'Surge Protector'): 11,
#   ('Case', 'Speakers', 'Thermal Paste'): 15,
#   ('Case', 'Speakers', 'UPS'): 16,
#   ('Case', 'Speakers', 'USB Hub'): 20,
#   ('Case', 'Speakers', 'Webcam'): 22,
#   ('Case', 'Surge Protector', 'Thermal Paste'): 14,
#   ('Case', 'Surge Protector', 'UPS'): 23,
#   ('Case', 'Surge Protector', 'USB Hub'): 19,
#   ('Case', 'Surge Protector', 'Webcam'): 19,
#   ('Case', 'Thermal Paste', 'UPS'): 24,
#   ('Case', 'Thermal Paste', 'USB Hub'): 12,
#   ('Case', 'Thermal Paste', 'Webcam'): 15,
#   ('Case', 'UPS', 'USB Hub'): 18,
#   ('Case', 'UPS', 'Webcam'): 13,
#   ('Case', 'USB Hub', 'Webcam'): 12,
#   ('Cooling Fan', 'External HDD', 'GPU'): 20,
#   ('Cooling Fan', 'External HDD', 'Graphics Tablet'): 19,
#   ('Cooling Fan', 'External HDD', 'HDD'): 25,
#   ('Cooling Fan', 'External HDD', 'Headset'): 16,
#   ('Cooling Fan', 'External HDD', 'Monitor'): 15,
#   ('Cooling Fan', 'External HDD', 'Motherboard'): 19,
#   ('Cooling Fan', 'External HDD', 'Mouse'): 20,
#   ('Cooling Fan', 'External HDD', 'Network Card'): 26,
#   ('Cooling Fan', 'External HDD', 'Optical Drive'): 16,
#   ('Cooling Fan', 'External HDD', 'Power Supply'): 16,
#   ('Cooling Fan', 'External HDD', 'RAM'): 15,
#   ('Cooling Fan', 'External HDD', 'RGB Lighting'): 23,
#   ('Cooling Fan', 'External HDD', 'SSD'): 17,
#   ('Cooling Fan', 'External HDD', 'Speakers'): 15,
#   ('Cooling Fan', 'External HDD', 'Surge Protector'): 21,
#   ('Cooling Fan', 'External HDD', 'Thermal Paste'): 18,
#   ('Cooling Fan', 'External HDD', 'UPS'): 15,
#   ('Cooling Fan', 'External HDD', 'USB Hub'): 17,
#   ('Cooling Fan', 'External HDD', 'Webcam'): 15,
#   ('Cooling Fan', 'GPU', 'Graphics Tablet'): 16,
#   ('Cooling Fan', 'GPU', 'HDD'): 18,
#   ('Cooling Fan', 'GPU', 'Headset'): 15,
#   ('Cooling Fan', 'GPU', 'Keyboard'): 11,
#   ('Cooling Fan', 'GPU', 'Monitor'): 21,
#   ('Cooling Fan', 'GPU', 'Motherboard'): 20,
#   ('Cooling Fan', 'GPU', 'Mouse'): 22,
#   ('Cooling Fan', 'GPU', 'Network Card'): 21,
#   ('Cooling Fan', 'GPU', 'Optical Drive'): 10,
#   ('Cooling Fan', 'GPU', 'Power Supply'): 14,
#   ('Cooling Fan', 'GPU', 'RGB Lighting'): 14,
#   ('Cooling Fan', 'GPU', 'SSD'): 12,
#   ('Cooling Fan', 'GPU', 'Sound Card'): 20,
#   ('Cooling Fan', 'GPU', 'Speakers'): 14,
#   ('Cooling Fan', 'GPU', 'Surge Protector'): 16,
#   ('Cooling Fan', 'GPU', 'UPS'): 12,
#   ('Cooling Fan', 'GPU', 'USB Hub'): 13,
#   ('Cooling Fan', 'GPU', 'Webcam'): 18,
#   ('Cooling Fan', 'Graphics Tablet', 'HDD'): 18,
#   ('Cooling Fan', 'Graphics Tablet', 'Headset'): 15,
#   ('Cooling Fan', 'Graphics Tablet', 'Keyboard'): 13,
#   ('Cooling Fan', 'Graphics Tablet', 'Monitor'): 19,
#   ('Cooling Fan', 'Graphics Tablet', 'Motherboard'): 20,
#   ('Cooling Fan', 'Graphics Tablet', 'Mouse'): 16,
#   ('Cooling Fan', 'Graphics Tablet', 'Network Card'): 18,
#   ('Cooling Fan', 'Graphics Tablet', 'Optical Drive'): 20,
#   ('Cooling Fan', 'Graphics Tablet', 'Power Supply'): 20,
#   ('Cooling Fan', 'Graphics Tablet', 'RAM'): 13,
#   ('Cooling Fan', 'Graphics Tablet', 'RGB Lighting'): 16,
#   ('Cooling Fan', 'Graphics Tablet', 'SSD'): 13,
#   ('Cooling Fan', 'Graphics Tablet', 'Sound Card'): 16,
#   ('Cooling Fan', 'Graphics Tablet', 'Speakers'): 12,
#   ('Cooling Fan', 'Graphics Tablet', 'Thermal Paste'): 15,
#   ('Cooling Fan', 'Graphics Tablet', 'UPS'): 11,
#   ('Cooling Fan', 'Graphics Tablet', 'USB Hub'): 19,
#   ('Cooling Fan', 'Graphics Tablet', 'Webcam'): 17,
#   ('Cooling Fan', 'HDD', 'Headset'): 23,
#   ('Cooling Fan', 'HDD', 'Monitor'): 16,
#   ('Cooling Fan', 'HDD', 'Motherboard'): 11,
#   ('Cooling Fan', 'HDD', 'Mouse'): 25,
#   ('Cooling Fan', 'HDD', 'Network Card'): 25,
#   ('Cooling Fan', 'HDD', 'Optical Drive'): 20,
#   ('Cooling Fan', 'HDD', 'Power Supply'): 19,
#   ('Cooling Fan', 'HDD', 'RAM'): 21,
#   ('Cooling Fan', 'HDD', 'RGB Lighting'): 24,
#   ('Cooling Fan', 'HDD', 'SSD'): 19,
#   ('Cooling Fan', 'HDD', 'Sound Card'): 21,
#   ('Cooling Fan', 'HDD', 'Speakers'): 18,
#   ('Cooling Fan', 'HDD', 'Surge Protector'): 23,
#   ('Cooling Fan', 'HDD', 'Thermal Paste'): 16,
#   ('Cooling Fan', 'HDD', 'UPS'): 17,
#   ('Cooling Fan', 'HDD', 'USB Hub'): 20,
#   ('Cooling Fan', 'HDD', 'Webcam'): 20,
#   ('Cooling Fan', 'Headset', 'Keyboard'): 10,
#   ('Cooling Fan', 'Headset', 'Monitor'): 14,
#   ('Cooling Fan', 'Headset', 'Motherboard'): 11,
#   ('Cooling Fan', 'Headset', 'Mouse'): 13,
#   ('Cooling Fan', 'Headset', 'Network Card'): 20,
#   ('Cooling Fan', 'Headset', 'Optical Drive'): 20,
#   ('Cooling Fan', 'Headset', 'Power Supply'): 18,
#   ('Cooling Fan', 'Headset', 'RAM'): 11,
#   ('Cooling Fan', 'Headset', 'RGB Lighting'): 16,
#   ('Cooling Fan', 'Headset', 'SSD'): 12,
#   ('Cooling Fan', 'Headset', 'Sound Card'): 20,
#   ('Cooling Fan', 'Headset', 'Speakers'): 15,
#   ('Cooling Fan', 'Headset', 'Surge Protector'): 13,
#   ('Cooling Fan', 'Headset', 'Thermal Paste'): 17,
#   ('Cooling Fan', 'Headset', 'UPS'): 14,
#   ('Cooling Fan', 'Headset', 'USB Hub'): 14,
#   ('Cooling Fan', 'Headset', 'Webcam'): 16,
#   ('Cooling Fan', 'Keyboard', 'Monitor'): 11,
#   ('Cooling Fan', 'Keyboard', 'Motherboard'): 17,
#   ('Cooling Fan', 'Keyboard', 'Mouse'): 16,
#   ('Cooling Fan', 'Keyboard', 'Network Card'): 16,
#   ('Cooling Fan', 'Keyboard', 'Optical Drive'): 17,
#   ('Cooling Fan', 'Keyboard', 'Power Supply'): 13,
#   ('Cooling Fan', 'Keyboard', 'RAM'): 15,
#   ('Cooling Fan', 'Keyboard', 'RGB Lighting'): 12,
#   ('Cooling Fan', 'Keyboard', 'SSD'): 17,
#   ('Cooling Fan', 'Keyboard', 'Sound Card'): 17,
#   ('Cooling Fan', 'Keyboard', 'Speakers'): 16,
#   ('Cooling Fan', 'Keyboard', 'Surge Protector'): 13,
#   ('Cooling Fan', 'Keyboard', 'Thermal Paste'): 11,
#   ('Cooling Fan', 'Keyboard', 'UPS'): 13,
#   ('Cooling Fan', 'Keyboard', 'USB Hub'): 11,
#   ('Cooling Fan', 'Keyboard', 'Webcam'): 13,
#   ('Cooling Fan', 'Monitor', 'Motherboard'): 19,
#   ('Cooling Fan', 'Monitor', 'Mouse'): 18,
#   ('Cooling Fan', 'Monitor', 'Network Card'): 18,
#   ('Cooling Fan', 'Monitor', 'Optical Drive'): 19,
#   ('Cooling Fan', 'Monitor', 'Power Supply'): 14,
#   ('Cooling Fan', 'Monitor', 'RGB Lighting'): 18,
#   ('Cooling Fan', 'Monitor', 'SSD'): 16,
#   ('Cooling Fan', 'Monitor', 'Sound Card'): 18,
#   ('Cooling Fan', 'Monitor', 'Speakers'): 16,
#   ('Cooling Fan', 'Monitor', 'Surge Protector'): 17,
#   ('Cooling Fan', 'Monitor', 'Thermal Paste'): 17,
#   ('Cooling Fan', 'Monitor', 'UPS'): 12,
#   ('Cooling Fan', 'Monitor', 'USB Hub'): 14,
#   ('Cooling Fan', 'Monitor', 'Webcam'): 18,
#   ('Cooling Fan', 'Motherboard', 'Mouse'): 20,
#   ('Cooling Fan', 'Motherboard', 'Network Card'): 22,
#   ('Cooling Fan', 'Motherboard', 'Optical Drive'): 22,
#   ('Cooling Fan', 'Motherboard', 'Power Supply'): 16,
#   ('Cooling Fan', 'Motherboard', 'RAM'): 13,
#   ('Cooling Fan', 'Motherboard', 'RGB Lighting'): 18,
#   ('Cooling Fan', 'Motherboard', 'SSD'): 15,
#   ('Cooling Fan', 'Motherboard', 'Sound Card'): 17,
#   ('Cooling Fan', 'Motherboard', 'Speakers'): 16,
#   ('Cooling Fan', 'Motherboard', 'Surge Protector'): 17,
#   ('Cooling Fan', 'Motherboard', 'Thermal Paste'): 19,
#   ('Cooling Fan', 'Motherboard', 'UPS'): 14,
#   ('Cooling Fan', 'Motherboard', 'USB Hub'): 17,
#   ('Cooling Fan', 'Motherboard', 'Webcam'): 21,
#   ('Cooling Fan', 'Mouse', 'Network Card'): 23,
#   ('Cooling Fan', 'Mouse', 'Optical Drive'): 13,
#   ('Cooling Fan', 'Mouse', 'Power Supply'): 19,
#   ('Cooling Fan', 'Mouse', 'RAM'): 14,
#   ('Cooling Fan', 'Mouse', 'RGB Lighting'): 21,
#   ('Cooling Fan', 'Mouse', 'SSD'): 17,
#   ('Cooling Fan', 'Mouse', 'Sound Card'): 17,
#   ('Cooling Fan', 'Mouse', 'Speakers'): 18,
#   ('Cooling Fan', 'Mouse', 'Surge Protector'): 21,
#   ('Cooling Fan', 'Mouse', 'Thermal Paste'): 17,
#   ('Cooling Fan', 'Mouse', 'UPS'): 13,
#   ('Cooling Fan', 'Mouse', 'USB Hub'): 16,
#   ('Cooling Fan', 'Mouse', 'Webcam'): 15,
#   ('Cooling Fan', 'Network Card', 'Optical Drive'): 21,
#   ('Cooling Fan', 'Network Card', 'Power Supply'): 13,
#   ('Cooling Fan', 'Network Card', 'RAM'): 17,
#   ('Cooling Fan', 'Network Card', 'RGB Lighting'): 19,
#   ('Cooling Fan', 'Network Card', 'SSD'): 19,
#   ('Cooling Fan', 'Network Card', 'Sound Card'): 22,
#   ('Cooling Fan', 'Network Card', 'Speakers'): 22,
#   ('Cooling Fan', 'Network Card', 'Surge Protector'): 21,
#   ('Cooling Fan', 'Network Card', 'Thermal Paste'): 21,
#   ('Cooling Fan', 'Network Card', 'UPS'): 14,
#   ('Cooling Fan', 'Network Card', 'USB Hub'): 18,
#   ('Cooling Fan', 'Network Card', 'Webcam'): 19,
#   ('Cooling Fan', 'Optical Drive', 'Power Supply'): 13,
#   ('Cooling Fan', 'Optical Drive', 'RAM'): 18,
#   ('Cooling Fan', 'Optical Drive', 'RGB Lighting'): 17,
#   ('Cooling Fan', 'Optical Drive', 'SSD'): 23,
#   ('Cooling Fan', 'Optical Drive', 'Sound Card'): 20,
#   ('Cooling Fan', 'Optical Drive', 'Speakers'): 19,
#   ('Cooling Fan', 'Optical Drive', 'Surge Protector'): 19,
#   ('Cooling Fan', 'Optical Drive', 'Thermal Paste'): 28,
#   ('Cooling Fan', 'Optical Drive', 'UPS'): 12,
#   ('Cooling Fan', 'Optical Drive', 'USB Hub'): 18,
#   ('Cooling Fan', 'Optical Drive', 'Webcam'): 23,
#   ('Cooling Fan', 'Power Supply', 'RGB Lighting'): 19,
#   ('Cooling Fan', 'Power Supply', 'SSD'): 21,
#   ('Cooling Fan', 'Power Supply', 'Sound Card'): 18,
#   ('Cooling Fan', 'Power Supply', 'Speakers'): 17,
#   ('Cooling Fan', 'Power Supply', 'Surge Protector'): 12,
#   ('Cooling Fan', 'Power Supply', 'Thermal Paste'): 14,
#   ('Cooling Fan', 'Power Supply', 'UPS'): 13,
#   ('Cooling Fan', 'Power Supply', 'USB Hub'): 19,
#   ('Cooling Fan', 'Power Supply', 'Webcam'): 13,
#   ('Cooling Fan', 'RAM', 'RGB Lighting'): 20,
#   ('Cooling Fan', 'RAM', 'SSD'): 15,
#   ('Cooling Fan', 'RAM', 'Sound Card'): 10,
#   ('Cooling Fan', 'RAM', 'Surge Protector'): 20,
#   ('Cooling Fan', 'RAM', 'Thermal Paste'): 10,
#   ('Cooling Fan', 'RAM', 'UPS'): 13,
#   ('Cooling Fan', 'RAM', 'USB Hub'): 16,
#   ('Cooling Fan', 'RAM', 'Webcam'): 14,
#   ('Cooling Fan', 'RGB Lighting', 'SSD'): 16,
#   ('Cooling Fan', 'RGB Lighting', 'Sound Card'): 14,
#   ('Cooling Fan', 'RGB Lighting', 'Speakers'): 12,
#   ('Cooling Fan', 'RGB Lighting', 'Surge Protector'): 23,
#   ('Cooling Fan', 'RGB Lighting', 'Thermal Paste'): 19,
#   ('Cooling Fan', 'RGB Lighting', 'UPS'): 19,
#   ('Cooling Fan', 'RGB Lighting', 'USB Hub'): 19,
#   ('Cooling Fan', 'RGB Lighting', 'Webcam'): 15,
#   ('Cooling Fan', 'SSD', 'Sound Card'): 16,
#   ('Cooling Fan', 'SSD', 'Speakers'): 16,
#   ('Cooling Fan', 'SSD', 'Surge Protector'): 16,
#   ('Cooling Fan', 'SSD', 'Thermal Paste'): 15,
#   ('Cooling Fan', 'SSD', 'UPS'): 15,
#   ('Cooling Fan', 'SSD', 'USB Hub'): 24,
#   ('Cooling Fan', 'SSD', 'Webcam'): 17,
#   ('Cooling Fan', 'Sound Card', 'Speakers'): 15,
#   ('Cooling Fan', 'Sound Card', 'Surge Protector'): 13,
#   ...},
#  4: {('CPU', 'CPU Cooler', 'Cooling Fan', 'Optical Drive'): 10,
#   ('CPU', 'Case', 'RAM', 'USB Hub'): 10,
#   ('CPU', 'Cooling Fan', 'External HDD', 'RGB Lighting'): 10,
#   ('CPU', 'Cooling Fan', 'GPU', 'Motherboard'): 10,
#   ('CPU', 'Cooling Fan', 'GPU', 'Network Card'): 10,
#   ('CPU', 'Cooling Fan', 'Graphics Tablet', 'Monitor'): 12,
#   ('CPU', 'Cooling Fan', 'Graphics Tablet', 'Motherboard'): 12,
#   ('CPU', 'Cooling Fan', 'Graphics Tablet', 'Mouse'): 10,
#   ('CPU', 'Cooling Fan', 'Monitor', 'Motherboard'): 10,
#   ('CPU', 'Cooling Fan', 'Monitor', 'Optical Drive'): 10,
#   ('CPU', 'Cooling Fan', 'Motherboard', 'Mouse'): 10,
#   ('CPU', 'Cooling Fan', 'Motherboard', 'Network Card'): 11,
#   ('CPU', 'Cooling Fan', 'Motherboard', 'Optical Drive'): 11,
#   ('CPU', 'Cooling Fan', 'Motherboard', 'Power Supply'): 10,
#   ('CPU', 'Cooling Fan', 'Motherboard', 'Sound Card'): 10,
#   ('CPU', 'External HDD', 'Mouse', 'USB Hub'): 11,
#   ('CPU', 'GPU', 'Monitor', 'Motherboard'): 11,
#   ('CPU', 'GPU', 'Network Card', 'Sound Card'): 10,
#   ('CPU', 'Headset', 'Network Card', 'Sound Card'): 11,
#   ('CPU', 'Headset', 'RGB Lighting', 'USB Hub'): 10,
#   ('CPU', 'Keyboard', 'Power Supply', 'Sound Card'): 11,
#   ('CPU', 'Monitor', 'Motherboard', 'Network Card'): 10,
#   ('CPU', 'Monitor', 'Network Card', 'Sound Card'): 10,
#   ('CPU', 'Power Supply', 'RGB Lighting', 'Sound Card'): 10,
#   ('CPU Cooler', 'Cooling Fan', 'External HDD', 'RGB Lighting'): 10,
#   ('CPU Cooler', 'GPU', 'Motherboard', 'RAM'): 11,
#   ('Case', 'External HDD', 'Power Supply', 'UPS'): 10,
#   ('Case', 'GPU', 'Mouse', 'Sound Card'): 10,
#   ('Case', 'Monitor', 'Thermal Paste', 'UPS'): 10,
#   ('Case', 'Motherboard', 'SSD', 'Webcam'): 11,
#   ('Cooling Fan', 'External HDD', 'HDD', 'UPS'): 10,
#   ('Cooling Fan', 'GPU', 'Monitor', 'Motherboard'): 10,
#   ('Cooling Fan', 'GPU', 'Monitor', 'Sound Card'): 10,
#   ('Cooling Fan', 'HDD', 'Headset', 'Optical Drive'): 11,
#   ('Cooling Fan', 'Headset', 'Sound Card', 'Thermal Paste'): 10,
#   ('Cooling Fan', 'Network Card', 'Optical Drive', 'Thermal Paste'): 11,
#   ('Cooling Fan', 'Optical Drive', 'Sound Card', 'Thermal Paste'): 12,
#   ('Cooling Fan', 'Surge Protector', 'USB Hub', 'Webcam'): 11,
#   ('External HDD', 'GPU', 'Speakers', 'Webcam'): 11,
#   ('External HDD', 'HDD', 'Network Card', 'Surge Protector'): 11,
#   ('External HDD', 'HDD', 'Power Supply', 'UPS'): 10,
#   ('External HDD', 'HDD', 'RGB Lighting', 'UPS'): 10,
#   ('External HDD', 'HDD', 'Surge Protector', 'UPS'): 11,
#   ('External HDD', 'Headset', 'Power Supply', 'UPS'): 10,
#   ('External HDD', 'Motherboard', 'Network Card', 'SSD'): 10,
#   ('External HDD', 'Motherboard', 'Power Supply', 'UPS'): 10,
#   ('External HDD', 'Motherboard', 'SSD', 'Speakers'): 10,
#   ('External HDD', 'Network Card', 'RAM', 'UPS'): 10,
#   ('External HDD', 'Network Card', 'Surge Protector', 'UPS'): 10,
#   ('External HDD', 'RAM', 'RGB Lighting', 'Speakers'): 10,
#   ('External HDD', 'SSD', 'Thermal Paste', 'Webcam'): 11,
#   ('GPU', 'Headset', 'RGB Lighting', 'Sound Card'): 10,
#   ('GPU', 'Motherboard', 'Sound Card', 'Webcam'): 10,
#   ('GPU', 'Mouse', 'Surge Protector', 'UPS'): 11,
#   ('GPU', 'RAM', 'Sound Card', 'Speakers'): 10,
#   ('GPU', 'Sound Card', 'Speakers', 'Surge Protector'): 10,
#   ('GPU', 'Sound Card', 'Speakers', 'UPS'): 10,
#   ('GPU', 'Sound Card', 'Speakers', 'Webcam'): 13,
#   ('GPU', 'Sound Card', 'Surge Protector', 'Webcam'): 14,
#   ('GPU', 'Speakers', 'Surge Protector', 'Webcam'): 10,
#   ('HDD', 'Motherboard', 'RGB Lighting', 'UPS'): 10,
#   ('HDD', 'Optical Drive', 'SSD', 'Webcam'): 10,
#   ('HDD', 'RAM', 'RGB Lighting', 'Sound Card'): 10,
#   ('HDD', 'RGB Lighting', 'Sound Card', 'Webcam'): 10,
#   ('HDD', 'RGB Lighting', 'Surge Protector', 'UPS'): 10,
#   ('Headset', 'Keyboard', 'Motherboard', 'UPS'): 10,
#   ('Headset', 'Motherboard', 'Mouse', 'RAM'): 10,
#   ('Headset', 'Motherboard', 'Surge Protector', 'UPS'): 10,
#   ('Keyboard', 'Motherboard', 'Network Card', 'SSD'): 10,
#   ('Keyboard', 'RAM', 'Surge Protector', 'UPS'): 10,
#   ('Monitor', 'Mouse', 'Optical Drive', 'Sound Card'): 10,
#   ('Monitor', 'RGB Lighting', 'Surge Protector', 'UPS'): 11,
#   ('Motherboard', 'Mouse', 'Surge Protector', 'Webcam'): 10,
#   ('Motherboard', 'Power Supply', 'Surge Protector', 'Thermal Paste'): 10,
#   ('Motherboard', 'SSD', 'Thermal Paste', 'Webcam'): 10,
#   ('Motherboard', 'Surge Protector', 'Thermal Paste', 'Webcam'): 11,
#   ('Mouse', 'Optical Drive', 'Sound Card', 'Thermal Paste'): 10,
#   ('Mouse', 'Power Supply', 'Surge Protector', 'UPS'): 10,
#   ('Optical Drive', 'RGB Lighting', 'Speakers', 'USB Hub'): 10,
#   ('Optical Drive', 'SSD', 'Thermal Paste', 'Webcam'): 10,
#   ('RAM', 'RGB Lighting', 'Thermal Paste', 'UPS'): 10,
#   ('RAM', 'Sound Card', 'Speakers', 'UPS'): 11}}

# %%
def printing_frequent_itemsets(f_sets:dict)->None:
    table = PrettyTable()
    table.field_names = ["Itemset Number","Itemset","Support"]
    for key, itemsets in f_sets.items():
        for itemset in itemsets:
            table.add_row([key, itemset, f_sets[key][itemset]])
    
    freq_df = pd.DataFrame(table.rows, columns=table.field_names)
    print(table)
    return freq_df

# %%
freq_df = printing_frequent_itemsets(L)
# Out:
# +----------------+---------------------------------------------------------------------+---------+
# | Itemset Number |                               Itemset                               | Support |
# +----------------+---------------------------------------------------------------------+---------+
# |       1        |                                 CPU                                 |   266   |
# |       1        |                              CPU Cooler                             |   244   |
# |       1        |                                 Case                                |   245   |
# |       1        |                             Cooling Fan                             |   248   |
# |       1        |                             External HDD                            |   250   |
# |       1        |                                 GPU                                 |   238   |
# |       1        |                           Graphics Tablet                           |   228   |
# |       1        |                                 HDD                                 |   259   |
# |       1        |                               Headset                               |   247   |
# |       1        |                               Keyboard                              |   239   |
# |       1        |                               Monitor                               |   224   |
# |       1        |                             Motherboard                             |   258   |
# |       1        |                                Mouse                                |   255   |
# |       1        |                             Network Card                            |   239   |
# |       1        |                            Optical Drive                            |   250   |
# |       1        |                             Power Supply                            |   236   |
# |       1        |                                 RAM                                 |   234   |
# |       1        |                             RGB Lighting                            |   242   |
# |       1        |                                 SSD                                 |   247   |
# |       1        |                              Sound Card                             |   284   |
# |       1        |                               Speakers                              |   249   |
# |       1        |                           Surge Protector                           |   260   |
# |       1        |                            Thermal Paste                            |   253   |
# |       1        |                                 UPS                                 |   250   |
# |       1        |                               USB Hub                               |   248   |
# |       1        |                                Webcam                               |   229   |
# |       2        |                        ('CPU', 'CPU Cooler')                        |    68   |
# |       2        |                           ('CPU', 'Case')                           |    68   |
# |       2        |                        ('CPU', 'Cooling Fan')                       |    67   |
# |       2        |                       ('CPU', 'External HDD')                       |    65   |
# |       2        |                            ('CPU', 'GPU')                           |    67   |
# |       2        |                      ('CPU', 'Graphics Tablet')                     |    62   |
# |       2        |                            ('CPU', 'HDD')                           |    57   |
# |       2        |                          ('CPU', 'Headset')                         |    66   |
# |       2        |                         ('CPU', 'Keyboard')                         |    71   |
# |       2        |                          ('CPU', 'Monitor')                         |    70   |
# |       2        |                        ('CPU', 'Motherboard')                       |    72   |
# |       2        |                           ('CPU', 'Mouse')                          |    68   |
# |       2        |                       ('CPU', 'Network Card')                       |    71   |
# |       2        |                       ('CPU', 'Optical Drive')                      |    67   |
# |       2        |                       ('CPU', 'Power Supply')                       |    65   |
# |       2        |                            ('CPU', 'RAM')                           |    56   |
# |       2        |                       ('CPU', 'RGB Lighting')                       |    79   |
# |       2        |                            ('CPU', 'SSD')                           |    67   |
# |       2        |                        ('CPU', 'Sound Card')                        |    84   |
# |       2        |                         ('CPU', 'Speakers')                         |    72   |
# |       2        |                      ('CPU', 'Surge Protector')                     |    69   |
# |       2        |                       ('CPU', 'Thermal Paste')                      |    53   |
# |       2        |                            ('CPU', 'UPS')                           |    62   |
# |       2        |                          ('CPU', 'USB Hub')                         |    69   |
# |       2        |                          ('CPU', 'Webcam')                          |    57   |
# |       2        |                        ('CPU Cooler', 'Case')                       |    62   |
# |       2        |                    ('CPU Cooler', 'Cooling Fan')                    |    61   |
# |       2        |                    ('CPU Cooler', 'External HDD')                   |    66   |
# |       2        |                        ('CPU Cooler', 'GPU')                        |    59   |
# |       2        |                  ('CPU Cooler', 'Graphics Tablet')                  |    51   |
# |       2        |                        ('CPU Cooler', 'HDD')                        |    59   |
# |       2        |                      ('CPU Cooler', 'Headset')                      |    60   |
# |       2        |                      ('CPU Cooler', 'Keyboard')                     |    58   |
# |       2        |                      ('CPU Cooler', 'Monitor')                      |    57   |
# |       2        |                    ('CPU Cooler', 'Motherboard')                    |    64   |
# |       2        |                       ('CPU Cooler', 'Mouse')                       |    71   |
# |       2        |                    ('CPU Cooler', 'Network Card')                   |    59   |
# |       2        |                   ('CPU Cooler', 'Optical Drive')                   |    61   |
# |       2        |                    ('CPU Cooler', 'Power Supply')                   |    49   |
# |       2        |                        ('CPU Cooler', 'RAM')                        |    63   |
# |       2        |                    ('CPU Cooler', 'RGB Lighting')                   |    56   |
# |       2        |                        ('CPU Cooler', 'SSD')                        |    63   |
# |       2        |                     ('CPU Cooler', 'Sound Card')                    |    70   |
# |       2        |                      ('CPU Cooler', 'Speakers')                     |    59   |
# |       2        |                  ('CPU Cooler', 'Surge Protector')                  |    67   |
# |       2        |                   ('CPU Cooler', 'Thermal Paste')                   |    62   |
# |       2        |                        ('CPU Cooler', 'UPS')                        |    55   |
# |       2        |                      ('CPU Cooler', 'USB Hub')                      |    64   |
# |       2        |                       ('CPU Cooler', 'Webcam')                      |    56   |
# |       2        |                       ('Case', 'Cooling Fan')                       |    63   |
# |       2        |                       ('Case', 'External HDD')                      |    56   |
# |       2        |                           ('Case', 'GPU')                           |    56   |
# |       2        |                     ('Case', 'Graphics Tablet')                     |    54   |
# |       2        |                           ('Case', 'HDD')                           |    68   |
# |       2        |                         ('Case', 'Headset')                         |    57   |
# |       2        |                         ('Case', 'Keyboard')                        |    46   |
# |       2        |                         ('Case', 'Monitor')                         |    61   |
# |       2        |                       ('Case', 'Motherboard')                       |    52   |
# |       2        |                          ('Case', 'Mouse')                          |    68   |
# |       2        |                       ('Case', 'Network Card')                      |    58   |
# |       2        |                      ('Case', 'Optical Drive')                      |    49   |
# |       2        |                       ('Case', 'Power Supply')                      |    61   |
# |       2        |                           ('Case', 'RAM')                           |    60   |
# |       2        |                       ('Case', 'RGB Lighting')                      |    59   |
# |       2        |                           ('Case', 'SSD')                           |    69   |
# |       2        |                        ('Case', 'Sound Card')                       |    61   |
# |       2        |                         ('Case', 'Speakers')                        |    57   |
# |       2        |                     ('Case', 'Surge Protector')                     |    66   |
# |       2        |                      ('Case', 'Thermal Paste')                      |    65   |
# |       2        |                           ('Case', 'UPS')                           |    67   |
# |       2        |                         ('Case', 'USB Hub')                         |    64   |
# |       2        |                          ('Case', 'Webcam')                         |    59   |
# |       2        |                   ('Cooling Fan', 'External HDD')                   |    68   |
# |       2        |                        ('Cooling Fan', 'GPU')                       |    57   |
# |       2        |                  ('Cooling Fan', 'Graphics Tablet')                 |    66   |
# |       2        |                        ('Cooling Fan', 'HDD')                       |    75   |
# |       2        |                      ('Cooling Fan', 'Headset')                     |    63   |
# |       2        |                     ('Cooling Fan', 'Keyboard')                     |    50   |
# |       2        |                      ('Cooling Fan', 'Monitor')                     |    63   |
# |       2        |                    ('Cooling Fan', 'Motherboard')                   |    65   |
# |       2        |                       ('Cooling Fan', 'Mouse')                      |    69   |
# |       2        |                   ('Cooling Fan', 'Network Card')                   |    79   |
# |       2        |                   ('Cooling Fan', 'Optical Drive')                  |    76   |
# |       2        |                   ('Cooling Fan', 'Power Supply')                   |    61   |
# |       2        |                        ('Cooling Fan', 'RAM')                       |    56   |
# |       2        |                   ('Cooling Fan', 'RGB Lighting')                   |    66   |
# |       2        |                        ('Cooling Fan', 'SSD')                       |    64   |
# |       2        |                    ('Cooling Fan', 'Sound Card')                    |    67   |
# |       2        |                     ('Cooling Fan', 'Speakers')                     |    57   |
# |       2        |                  ('Cooling Fan', 'Surge Protector')                 |    72   |
# |       2        |                   ('Cooling Fan', 'Thermal Paste')                  |    62   |
# |       2        |                        ('Cooling Fan', 'UPS')                       |    49   |
# |       2        |                      ('Cooling Fan', 'USB Hub')                     |    66   |
# |       2        |                      ('Cooling Fan', 'Webcam')                      |    65   |
# |       2        |                       ('External HDD', 'GPU')                       |    66   |
# |       2        |                 ('External HDD', 'Graphics Tablet')                 |    53   |
# |       2        |                       ('External HDD', 'HDD')                       |    71   |
# |       2        |                     ('External HDD', 'Headset')                     |    74   |
# |       2        |                     ('External HDD', 'Keyboard')                    |    64   |
# |       2        |                     ('External HDD', 'Monitor')                     |    52   |
# |       2        |                   ('External HDD', 'Motherboard')                   |    69   |
# |       2        |                      ('External HDD', 'Mouse')                      |    64   |
# |       2        |                   ('External HDD', 'Network Card')                  |    62   |
# |       2        |                  ('External HDD', 'Optical Drive')                  |    66   |
# |       2        |                   ('External HDD', 'Power Supply')                  |    64   |
# |       2        |                       ('External HDD', 'RAM')                       |    62   |
# |       2        |                   ('External HDD', 'RGB Lighting')                  |    60   |
# |       2        |                       ('External HDD', 'SSD')                       |    64   |
# |       2        |                    ('External HDD', 'Sound Card')                   |    58   |
# |       2        |                     ('External HDD', 'Speakers')                    |    71   |
# |       2        |                 ('External HDD', 'Surge Protector')                 |    66   |
# |       2        |                  ('External HDD', 'Thermal Paste')                  |    71   |
# |       2        |                       ('External HDD', 'UPS')                       |    67   |
# |       2        |                     ('External HDD', 'USB Hub')                     |    61   |
# |       2        |                      ('External HDD', 'Webcam')                     |    51   |
# |       2        |                      ('GPU', 'Graphics Tablet')                     |    54   |
# |       2        |                            ('GPU', 'HDD')                           |    58   |
# |       2        |                          ('GPU', 'Headset')                         |    55   |
# |       2        |                         ('GPU', 'Keyboard')                         |    53   |
# |       2        |                          ('GPU', 'Monitor')                         |    58   |
# |       2        |                        ('GPU', 'Motherboard')                       |    65   |
# |       2        |                           ('GPU', 'Mouse')                          |    61   |
# |       2        |                       ('GPU', 'Network Card')                       |    64   |
# |       2        |                       ('GPU', 'Optical Drive')                      |    57   |
# |       2        |                       ('GPU', 'Power Supply')                       |    56   |
# |       2        |                            ('GPU', 'RAM')                           |    55   |
# |       2        |                       ('GPU', 'RGB Lighting')                       |    53   |
# |       2        |                            ('GPU', 'SSD')                           |    58   |
# |       2        |                        ('GPU', 'Sound Card')                        |    82   |
# |       2        |                         ('GPU', 'Speakers')                         |    71   |
# |       2        |                      ('GPU', 'Surge Protector')                     |    64   |
# |       2        |                       ('GPU', 'Thermal Paste')                      |    50   |
# |       2        |                            ('GPU', 'UPS')                           |    66   |
# |       2        |                          ('GPU', 'USB Hub')                         |    52   |
# |       2        |                          ('GPU', 'Webcam')                          |    62   |
# |       2        |                      ('Graphics Tablet', 'HDD')                     |    57   |
# |       2        |                    ('Graphics Tablet', 'Headset')                   |    56   |
# |       2        |                   ('Graphics Tablet', 'Keyboard')                   |    57   |
# |       2        |                    ('Graphics Tablet', 'Monitor')                   |    49   |
# |       2        |                  ('Graphics Tablet', 'Motherboard')                 |    68   |
# |       2        |                     ('Graphics Tablet', 'Mouse')                    |    56   |
# |       2        |                 ('Graphics Tablet', 'Network Card')                 |    53   |
# |       2        |                 ('Graphics Tablet', 'Optical Drive')                |    60   |
# |       2        |                 ('Graphics Tablet', 'Power Supply')                 |    57   |
# |       2        |                      ('Graphics Tablet', 'RAM')                     |    46   |
# |       2        |                 ('Graphics Tablet', 'RGB Lighting')                 |    51   |
# |       2        |                      ('Graphics Tablet', 'SSD')                     |    57   |
# |       2        |                  ('Graphics Tablet', 'Sound Card')                  |    58   |
# |       2        |                   ('Graphics Tablet', 'Speakers')                   |    55   |
# |       2        |                ('Graphics Tablet', 'Surge Protector')               |    57   |
# |       2        |                 ('Graphics Tablet', 'Thermal Paste')                |    60   |
# |       2        |                      ('Graphics Tablet', 'UPS')                     |    49   |
# |       2        |                    ('Graphics Tablet', 'USB Hub')                   |    60   |
# |       2        |                    ('Graphics Tablet', 'Webcam')                    |    63   |
# |       2        |                          ('HDD', 'Headset')                         |    64   |
# |       2        |                         ('HDD', 'Keyboard')                         |    55   |
# |       2        |                          ('HDD', 'Monitor')                         |    49   |
# |       2        |                        ('HDD', 'Motherboard')                       |    52   |
# |       2        |                           ('HDD', 'Mouse')                          |    67   |
# |       2        |                       ('HDD', 'Network Card')                       |    62   |
# |       2        |                       ('HDD', 'Optical Drive')                      |    69   |
# |       2        |                       ('HDD', 'Power Supply')                       |    54   |
# |       2        |                            ('HDD', 'RAM')                           |    69   |
# |       2        |                       ('HDD', 'RGB Lighting')                       |    70   |
# |       2        |                            ('HDD', 'SSD')                           |    63   |
# |       2        |                        ('HDD', 'Sound Card')                        |    73   |
# |       2        |                         ('HDD', 'Speakers')                         |    59   |
# |       2        |                      ('HDD', 'Surge Protector')                     |    71   |
# |       2        |                       ('HDD', 'Thermal Paste')                      |    65   |
# |       2        |                            ('HDD', 'UPS')                           |    65   |
# |       2        |                          ('HDD', 'USB Hub')                         |    67   |
# |       2        |                          ('HDD', 'Webcam')                          |    65   |
# |       2        |                       ('Headset', 'Keyboard')                       |    70   |
# |       2        |                        ('Headset', 'Monitor')                       |    47   |
# |       2        |                      ('Headset', 'Motherboard')                     |    66   |
# |       2        |                         ('Headset', 'Mouse')                        |    65   |
# |       2        |                     ('Headset', 'Network Card')                     |    64   |
# |       2        |                     ('Headset', 'Optical Drive')                    |    67   |
# |       2        |                     ('Headset', 'Power Supply')                     |    58   |
# |       2        |                          ('Headset', 'RAM')                         |    56   |
# |       2        |                     ('Headset', 'RGB Lighting')                     |    66   |
# |       2        |                          ('Headset', 'SSD')                         |    58   |
# |       2        |                      ('Headset', 'Sound Card')                      |    65   |
# |       2        |                       ('Headset', 'Speakers')                       |    62   |
# |       2        |                    ('Headset', 'Surge Protector')                   |    58   |
# |       2        |                     ('Headset', 'Thermal Paste')                    |    67   |
# |       2        |                          ('Headset', 'UPS')                         |    74   |
# |       2        |                        ('Headset', 'USB Hub')                       |    62   |
# |       2        |                        ('Headset', 'Webcam')                        |    57   |
# |       2        |                       ('Keyboard', 'Monitor')                       |    55   |
# |       2        |                     ('Keyboard', 'Motherboard')                     |    61   |
# |       2        |                        ('Keyboard', 'Mouse')                        |    62   |
# |       2        |                     ('Keyboard', 'Network Card')                    |    58   |
# |       2        |                    ('Keyboard', 'Optical Drive')                    |    64   |
# |       2        |                     ('Keyboard', 'Power Supply')                    |    59   |
# |       2        |                         ('Keyboard', 'RAM')                         |    62   |
# |       2        |                     ('Keyboard', 'RGB Lighting')                    |    55   |
# |       2        |                         ('Keyboard', 'SSD')                         |    60   |
# |       2        |                      ('Keyboard', 'Sound Card')                     |    71   |
# |       2        |                       ('Keyboard', 'Speakers')                      |    61   |
# |       2        |                   ('Keyboard', 'Surge Protector')                   |    55   |
# |       2        |                    ('Keyboard', 'Thermal Paste')                    |    61   |
# |       2        |                         ('Keyboard', 'UPS')                         |    60   |
# |       2        |                       ('Keyboard', 'USB Hub')                       |    64   |
# |       2        |                        ('Keyboard', 'Webcam')                       |    60   |
# |       2        |                      ('Monitor', 'Motherboard')                     |    61   |
# |       2        |                         ('Monitor', 'Mouse')                        |    64   |
# |       2        |                     ('Monitor', 'Network Card')                     |    54   |
# |       2        |                     ('Monitor', 'Optical Drive')                    |    55   |
# |       2        |                     ('Monitor', 'Power Supply')                     |    49   |
# |       2        |                          ('Monitor', 'RAM')                         |    48   |
# |       2        |                     ('Monitor', 'RGB Lighting')                     |    54   |
# |       2        |                          ('Monitor', 'SSD')                         |    62   |
# |       2        |                      ('Monitor', 'Sound Card')                      |    71   |
# |       2        |                       ('Monitor', 'Speakers')                       |    60   |
# |       2        |                    ('Monitor', 'Surge Protector')                   |    50   |
# |       2        |                     ('Monitor', 'Thermal Paste')                    |    59   |
# |       2        |                          ('Monitor', 'UPS')                         |    66   |
# |       2        |                        ('Monitor', 'USB Hub')                       |    54   |
# |       2        |                        ('Monitor', 'Webcam')                        |    51   |
# |       2        |                       ('Motherboard', 'Mouse')                      |    72   |
# |       2        |                   ('Motherboard', 'Network Card')                   |    57   |
# |       2        |                   ('Motherboard', 'Optical Drive')                  |    64   |
# |       2        |                   ('Motherboard', 'Power Supply')                   |    60   |
# |       2        |                        ('Motherboard', 'RAM')                       |    60   |
# |       2        |                   ('Motherboard', 'RGB Lighting')                   |    61   |
# |       2        |                        ('Motherboard', 'SSD')                       |    67   |
# |       2        |                    ('Motherboard', 'Sound Card')                    |    65   |
# |       2        |                     ('Motherboard', 'Speakers')                     |    65   |
# |       2        |                  ('Motherboard', 'Surge Protector')                 |    75   |
# |       2        |                   ('Motherboard', 'Thermal Paste')                  |    74   |
# |       2        |                        ('Motherboard', 'UPS')                       |    74   |
# |       2        |                      ('Motherboard', 'USB Hub')                     |    69   |
# |       2        |                      ('Motherboard', 'Webcam')                      |    65   |
# |       2        |                      ('Mouse', 'Network Card')                      |    62   |
# |       2        |                      ('Mouse', 'Optical Drive')                     |    60   |
# |       2        |                      ('Mouse', 'Power Supply')                      |    66   |
# |       2        |                           ('Mouse', 'RAM')                          |    58   |
# |       2        |                      ('Mouse', 'RGB Lighting')                      |    70   |
# |       2        |                           ('Mouse', 'SSD')                          |    68   |
# |       2        |                       ('Mouse', 'Sound Card')                       |    69   |
# |       2        |                        ('Mouse', 'Speakers')                        |    65   |
# |       2        |                     ('Mouse', 'Surge Protector')                    |    70   |
# |       2        |                      ('Mouse', 'Thermal Paste')                     |    70   |
# |       2        |                           ('Mouse', 'UPS')                          |    68   |
# |       2        |                         ('Mouse', 'USB Hub')                        |    65   |
# |       2        |                         ('Mouse', 'Webcam')                         |    56   |
# |       2        |                  ('Network Card', 'Optical Drive')                  |    52   |
# |       2        |                   ('Network Card', 'Power Supply')                  |    51   |
# |       2        |                       ('Network Card', 'RAM')                       |    54   |
# |       2        |                   ('Network Card', 'RGB Lighting')                  |    57   |
# |       2        |                       ('Network Card', 'SSD')                       |    55   |
# |       2        |                    ('Network Card', 'Sound Card')                   |    73   |
# |       2        |                     ('Network Card', 'Speakers')                    |    55   |
# |       2        |                 ('Network Card', 'Surge Protector')                 |    63   |
# |       2        |                  ('Network Card', 'Thermal Paste')                  |    55   |
# |       2        |                       ('Network Card', 'UPS')                       |    63   |
# |       2        |                     ('Network Card', 'USB Hub')                     |    53   |
# |       2        |                      ('Network Card', 'Webcam')                     |    55   |
# |       2        |                  ('Optical Drive', 'Power Supply')                  |    58   |
# |       2        |                       ('Optical Drive', 'RAM')                      |    56   |
# |       2        |                  ('Optical Drive', 'RGB Lighting')                  |    60   |
# |       2        |                       ('Optical Drive', 'SSD')                      |    69   |
# |       2        |                   ('Optical Drive', 'Sound Card')                   |    77   |
# |       2        |                    ('Optical Drive', 'Speakers')                    |    62   |
# |       2        |                 ('Optical Drive', 'Surge Protector')                |    54   |
# |       2        |                  ('Optical Drive', 'Thermal Paste')                 |    82   |
# |       2        |                       ('Optical Drive', 'UPS')                      |    55   |
# |       2        |                     ('Optical Drive', 'USB Hub')                    |    62   |
# |       2        |                     ('Optical Drive', 'Webcam')                     |    71   |
# |       2        |                       ('Power Supply', 'RAM')                       |    46   |
# |       2        |                   ('Power Supply', 'RGB Lighting')                  |    62   |
# |       2        |                       ('Power Supply', 'SSD')                       |    60   |
# |       2        |                    ('Power Supply', 'Sound Card')                   |    65   |
# |       2        |                     ('Power Supply', 'Speakers')                    |    58   |
# |       2        |                 ('Power Supply', 'Surge Protector')                 |    61   |
# |       2        |                  ('Power Supply', 'Thermal Paste')                  |    60   |
# |       2        |                       ('Power Supply', 'UPS')                       |    70   |
# |       2        |                     ('Power Supply', 'USB Hub')                     |    70   |
# |       2        |                      ('Power Supply', 'Webcam')                     |    53   |
# |       2        |                       ('RAM', 'RGB Lighting')                       |    64   |
# |       2        |                            ('RAM', 'SSD')                           |    63   |
# |       2        |                        ('RAM', 'Sound Card')                        |    64   |
# |       2        |                         ('RAM', 'Speakers')                         |    59   |
# |       2        |                      ('RAM', 'Surge Protector')                     |    68   |
# |       2        |                       ('RAM', 'Thermal Paste')                      |    52   |
# |       2        |                            ('RAM', 'UPS')                           |    63   |
# |       2        |                          ('RAM', 'USB Hub')                         |    61   |
# |       2        |                          ('RAM', 'Webcam')                          |    55   |
# |       2        |                       ('RGB Lighting', 'SSD')                       |    62   |
# |       2        |                    ('RGB Lighting', 'Sound Card')                   |    66   |
# |       2        |                     ('RGB Lighting', 'Speakers')                    |    59   |
# |       2        |                 ('RGB Lighting', 'Surge Protector')                 |    69   |
# |       2        |                  ('RGB Lighting', 'Thermal Paste')                  |    63   |
# |       2        |                       ('RGB Lighting', 'UPS')                       |    68   |
# |       2        |                     ('RGB Lighting', 'USB Hub')                     |    62   |
# |       2        |                      ('RGB Lighting', 'Webcam')                     |    56   |
# |       2        |                        ('SSD', 'Sound Card')                        |    69   |
# |       2        |                         ('SSD', 'Speakers')                         |    60   |
# |       2        |                      ('SSD', 'Surge Protector')                     |    63   |
# |       2        |                       ('SSD', 'Thermal Paste')                      |    64   |
# |       2        |                            ('SSD', 'UPS')                           |    59   |
# |       2        |                          ('SSD', 'USB Hub')                         |    75   |
# |       2        |                          ('SSD', 'Webcam')                          |    61   |
# |       2        |                      ('Sound Card', 'Speakers')                     |    71   |
# |       2        |                  ('Sound Card', 'Surge Protector')                  |    58   |
# |       2        |                   ('Sound Card', 'Thermal Paste')                   |    81   |
# |       2        |                        ('Sound Card', 'UPS')                        |    79   |
# |       2        |                      ('Sound Card', 'USB Hub')                      |    61   |
# |       2        |                       ('Sound Card', 'Webcam')                      |    67   |
# |       2        |                   ('Speakers', 'Surge Protector')                   |    61   |
# |       2        |                    ('Speakers', 'Thermal Paste')                    |    62   |
# |       2        |                         ('Speakers', 'UPS')                         |    63   |
# |       2        |                       ('Speakers', 'USB Hub')                       |    65   |
# |       2        |                        ('Speakers', 'Webcam')                       |    64   |
# |       2        |                 ('Surge Protector', 'Thermal Paste')                |    59   |
# |       2        |                      ('Surge Protector', 'UPS')                     |    81   |
# |       2        |                    ('Surge Protector', 'USB Hub')                   |    75   |
# |       2        |                    ('Surge Protector', 'Webcam')                    |    74   |
# |       2        |                       ('Thermal Paste', 'UPS')                      |    70   |
# |       2        |                     ('Thermal Paste', 'USB Hub')                    |    59   |
# |       2        |                     ('Thermal Paste', 'Webcam')                     |    59   |
# |       2        |                          ('UPS', 'USB Hub')                         |    60   |
# |       2        |                          ('UPS', 'Webcam')                          |    50   |
# |       2        |                        ('USB Hub', 'Webcam')                        |    58   |
# |       3        |                    ('CPU', 'CPU Cooler', 'Case')                    |    13   |
# |       3        |                 ('CPU', 'CPU Cooler', 'Cooling Fan')                |    21   |
# |       3        |                ('CPU', 'CPU Cooler', 'External HDD')                |    21   |
# |       3        |                     ('CPU', 'CPU Cooler', 'GPU')                    |    18   |
# |       3        |               ('CPU', 'CPU Cooler', 'Graphics Tablet')              |    16   |
# |       3        |                     ('CPU', 'CPU Cooler', 'HDD')                    |    15   |
# |       3        |                   ('CPU', 'CPU Cooler', 'Headset')                  |    13   |
# |       3        |                  ('CPU', 'CPU Cooler', 'Keyboard')                  |    16   |
# |       3        |                   ('CPU', 'CPU Cooler', 'Monitor')                  |    15   |
# |       3        |                 ('CPU', 'CPU Cooler', 'Motherboard')                |    19   |
# |       3        |                    ('CPU', 'CPU Cooler', 'Mouse')                   |    19   |
# |       3        |                ('CPU', 'CPU Cooler', 'Network Card')                |    15   |
# |       3        |                ('CPU', 'CPU Cooler', 'Optical Drive')               |    23   |
# |       3        |                ('CPU', 'CPU Cooler', 'Power Supply')                |    13   |
# |       3        |                     ('CPU', 'CPU Cooler', 'RAM')                    |    12   |
# |       3        |                ('CPU', 'CPU Cooler', 'RGB Lighting')                |    19   |
# |       3        |                     ('CPU', 'CPU Cooler', 'SSD')                    |    17   |
# |       3        |                 ('CPU', 'CPU Cooler', 'Sound Card')                 |    21   |
# |       3        |                  ('CPU', 'CPU Cooler', 'Speakers')                  |    17   |
# |       3        |               ('CPU', 'CPU Cooler', 'Surge Protector')              |    17   |
# |       3        |                ('CPU', 'CPU Cooler', 'Thermal Paste')               |    14   |
# |       3        |                     ('CPU', 'CPU Cooler', 'UPS')                    |    13   |
# |       3        |                   ('CPU', 'CPU Cooler', 'USB Hub')                  |    18   |
# |       3        |                   ('CPU', 'CPU Cooler', 'Webcam')                   |    19   |
# |       3        |                    ('CPU', 'Case', 'Cooling Fan')                   |    18   |
# |       3        |                   ('CPU', 'Case', 'External HDD')                   |    16   |
# |       3        |                        ('CPU', 'Case', 'GPU')                       |    16   |
# |       3        |                  ('CPU', 'Case', 'Graphics Tablet')                 |    17   |
# |       3        |                        ('CPU', 'Case', 'HDD')                       |    19   |
# |       3        |                      ('CPU', 'Case', 'Headset')                     |    14   |
# |       3        |                     ('CPU', 'Case', 'Keyboard')                     |    14   |
# |       3        |                      ('CPU', 'Case', 'Monitor')                     |    13   |
# |       3        |                    ('CPU', 'Case', 'Motherboard')                   |    18   |
# |       3        |                       ('CPU', 'Case', 'Mouse')                      |    15   |
# |       3        |                   ('CPU', 'Case', 'Network Card')                   |    17   |
# |       3        |                   ('CPU', 'Case', 'Optical Drive')                  |    18   |
# |       3        |                   ('CPU', 'Case', 'Power Supply')                   |    16   |
# |       3        |                        ('CPU', 'Case', 'RAM')                       |    22   |
# |       3        |                   ('CPU', 'Case', 'RGB Lighting')                   |    23   |
# |       3        |                        ('CPU', 'Case', 'SSD')                       |    17   |
# |       3        |                    ('CPU', 'Case', 'Sound Card')                    |    19   |
# |       3        |                     ('CPU', 'Case', 'Speakers')                     |    16   |
# |       3        |                  ('CPU', 'Case', 'Surge Protector')                 |    20   |
# |       3        |                   ('CPU', 'Case', 'Thermal Paste')                  |    18   |
# |       3        |                        ('CPU', 'Case', 'UPS')                       |    14   |
# |       3        |                      ('CPU', 'Case', 'USB Hub')                     |    23   |
# |       3        |                      ('CPU', 'Case', 'Webcam')                      |    11   |
# |       3        |                ('CPU', 'Cooling Fan', 'External HDD')               |    17   |
# |       3        |                    ('CPU', 'Cooling Fan', 'GPU')                    |    17   |
# |       3        |              ('CPU', 'Cooling Fan', 'Graphics Tablet')              |    26   |
# |       3        |                    ('CPU', 'Cooling Fan', 'HDD')                    |    13   |
# |       3        |                  ('CPU', 'Cooling Fan', 'Headset')                  |    15   |
# |       3        |                  ('CPU', 'Cooling Fan', 'Keyboard')                 |    17   |
# |       3        |                  ('CPU', 'Cooling Fan', 'Monitor')                  |    25   |
# |       3        |                ('CPU', 'Cooling Fan', 'Motherboard')                |    27   |
# |       3        |                   ('CPU', 'Cooling Fan', 'Mouse')                   |    21   |
# |       3        |                ('CPU', 'Cooling Fan', 'Network Card')               |    21   |
# |       3        |               ('CPU', 'Cooling Fan', 'Optical Drive')               |    23   |
# |       3        |                ('CPU', 'Cooling Fan', 'Power Supply')               |    16   |
# |       3        |                    ('CPU', 'Cooling Fan', 'RAM')                    |    14   |
# |       3        |                ('CPU', 'Cooling Fan', 'RGB Lighting')               |    22   |
# |       3        |                    ('CPU', 'Cooling Fan', 'SSD')                    |    17   |
# |       3        |                 ('CPU', 'Cooling Fan', 'Sound Card')                |    21   |
# |       3        |                  ('CPU', 'Cooling Fan', 'Speakers')                 |    14   |
# |       3        |              ('CPU', 'Cooling Fan', 'Surge Protector')              |    20   |
# |       3        |               ('CPU', 'Cooling Fan', 'Thermal Paste')               |    14   |
# |       3        |                    ('CPU', 'Cooling Fan', 'UPS')                    |    12   |
# |       3        |                  ('CPU', 'Cooling Fan', 'USB Hub')                  |    13   |
# |       3        |                   ('CPU', 'Cooling Fan', 'Webcam')                  |    16   |
# |       3        |              ('CPU', 'External HDD', 'Graphics Tablet')             |    14   |
# |       3        |                    ('CPU', 'External HDD', 'HDD')                   |    13   |
# |       3        |                  ('CPU', 'External HDD', 'Headset')                 |    18   |
# |       3        |                 ('CPU', 'External HDD', 'Keyboard')                 |    21   |
# |       3        |                  ('CPU', 'External HDD', 'Monitor')                 |    15   |
# |       3        |                ('CPU', 'External HDD', 'Motherboard')               |    17   |
# |       3        |                   ('CPU', 'External HDD', 'Mouse')                  |    21   |
# |       3        |               ('CPU', 'External HDD', 'Network Card')               |    13   |
# |       3        |               ('CPU', 'External HDD', 'Optical Drive')              |    18   |
# |       3        |               ('CPU', 'External HDD', 'Power Supply')               |    15   |
# |       3        |                    ('CPU', 'External HDD', 'RAM')                   |    14   |
# |       3        |               ('CPU', 'External HDD', 'RGB Lighting')               |    23   |
# |       3        |                    ('CPU', 'External HDD', 'SSD')                   |    14   |
# |       3        |                ('CPU', 'External HDD', 'Sound Card')                |    16   |
# |       3        |                 ('CPU', 'External HDD', 'Speakers')                 |    19   |
# |       3        |              ('CPU', 'External HDD', 'Surge Protector')             |    19   |
# |       3        |               ('CPU', 'External HDD', 'Thermal Paste')              |    13   |
# |       3        |                    ('CPU', 'External HDD', 'UPS')                   |    17   |
# |       3        |                  ('CPU', 'External HDD', 'USB Hub')                 |    25   |
# |       3        |                  ('CPU', 'External HDD', 'Webcam')                  |    10   |
# |       3        |                  ('CPU', 'GPU', 'Graphics Tablet')                  |    19   |
# |       3        |                        ('CPU', 'GPU', 'HDD')                        |    17   |
# |       3        |                      ('CPU', 'GPU', 'Headset')                      |    14   |
# |       3        |                      ('CPU', 'GPU', 'Keyboard')                     |    20   |
# |       3        |                      ('CPU', 'GPU', 'Monitor')                      |    19   |
# |       3        |                    ('CPU', 'GPU', 'Motherboard')                    |    22   |
# |       3        |                       ('CPU', 'GPU', 'Mouse')                       |    19   |
# |       3        |                    ('CPU', 'GPU', 'Network Card')                   |    24   |
# |       3        |                   ('CPU', 'GPU', 'Optical Drive')                   |    15   |
# |       3        |                    ('CPU', 'GPU', 'Power Supply')                   |    18   |
# |       3        |                        ('CPU', 'GPU', 'RAM')                        |    13   |
# |       3        |                    ('CPU', 'GPU', 'RGB Lighting')                   |    13   |
# |       3        |                        ('CPU', 'GPU', 'SSD')                        |    16   |
# |       3        |                     ('CPU', 'GPU', 'Sound Card')                    |    24   |
# |       3        |                      ('CPU', 'GPU', 'Speakers')                     |    22   |
# |       3        |                  ('CPU', 'GPU', 'Surge Protector')                  |    16   |
# |       3        |                   ('CPU', 'GPU', 'Thermal Paste')                   |    17   |
# |       3        |                        ('CPU', 'GPU', 'UPS')                        |    14   |
# |       3        |                      ('CPU', 'GPU', 'USB Hub')                      |    17   |
# |       3        |                       ('CPU', 'GPU', 'Webcam')                      |    18   |
# |       3        |                  ('CPU', 'Graphics Tablet', 'HDD')                  |    10   |
# |       3        |                ('CPU', 'Graphics Tablet', 'Headset')                |    12   |
# |       3        |                ('CPU', 'Graphics Tablet', 'Keyboard')               |    14   |
# |       3        |                ('CPU', 'Graphics Tablet', 'Monitor')                |    21   |
# |       3        |              ('CPU', 'Graphics Tablet', 'Motherboard')              |    19   |
# |       3        |                 ('CPU', 'Graphics Tablet', 'Mouse')                 |    19   |
# |       3        |              ('CPU', 'Graphics Tablet', 'Network Card')             |    16   |
# |       3        |             ('CPU', 'Graphics Tablet', 'Optical Drive')             |    18   |
# |       3        |              ('CPU', 'Graphics Tablet', 'Power Supply')             |    17   |
# |       3        |                  ('CPU', 'Graphics Tablet', 'RAM')                  |    10   |
# |       3        |              ('CPU', 'Graphics Tablet', 'RGB Lighting')             |    17   |
# |       3        |                  ('CPU', 'Graphics Tablet', 'SSD')                  |    16   |
# |       3        |               ('CPU', 'Graphics Tablet', 'Sound Card')              |    18   |
# |       3        |                ('CPU', 'Graphics Tablet', 'Speakers')               |    15   |
# |       3        |            ('CPU', 'Graphics Tablet', 'Surge Protector')            |    12   |
# |       3        |             ('CPU', 'Graphics Tablet', 'Thermal Paste')             |    12   |
# |       3        |                ('CPU', 'Graphics Tablet', 'USB Hub')                |    15   |
# |       3        |                 ('CPU', 'Graphics Tablet', 'Webcam')                |    15   |
# |       3        |                      ('CPU', 'HDD', 'Headset')                      |    21   |
# |       3        |                      ('CPU', 'HDD', 'Keyboard')                     |    13   |
# |       3        |                      ('CPU', 'HDD', 'Monitor')                      |    14   |
# ...
# |       3        |                  ('RGB Lighting', 'SSD', 'USB Hub')                 |    20   |
# |       3        |                  ('RGB Lighting', 'SSD', 'Webcam')                  |    18   |
# |       3        |              ('RGB Lighting', 'Sound Card', 'Speakers')             |    17   |
# |       3        |          ('RGB Lighting', 'Sound Card', 'Surge Protector')          |    15   |
# |       3        |           ('RGB Lighting', 'Sound Card', 'Thermal Paste')           |    21   |
# |       3        |                ('RGB Lighting', 'Sound Card', 'UPS')                |    16   |
# |       3        |              ('RGB Lighting', 'Sound Card', 'USB Hub')              |    13   |
# |       3        |               ('RGB Lighting', 'Sound Card', 'Webcam')              |    19   |
# |       3        |           ('RGB Lighting', 'Speakers', 'Surge Protector')           |    11   |
# |       3        |            ('RGB Lighting', 'Speakers', 'Thermal Paste')            |    18   |
# |       3        |                 ('RGB Lighting', 'Speakers', 'UPS')                 |    13   |
# |       3        |               ('RGB Lighting', 'Speakers', 'USB Hub')               |    18   |
# |       3        |                ('RGB Lighting', 'Speakers', 'Webcam')               |    19   |
# |       3        |         ('RGB Lighting', 'Surge Protector', 'Thermal Paste')        |    14   |
# |       3        |              ('RGB Lighting', 'Surge Protector', 'UPS')             |    26   |
# |       3        |            ('RGB Lighting', 'Surge Protector', 'USB Hub')           |    16   |
# |       3        |            ('RGB Lighting', 'Surge Protector', 'Webcam')            |    14   |
# |       3        |               ('RGB Lighting', 'Thermal Paste', 'UPS')              |    22   |
# |       3        |             ('RGB Lighting', 'Thermal Paste', 'USB Hub')            |    17   |
# |       3        |             ('RGB Lighting', 'Thermal Paste', 'Webcam')             |    14   |
# |       3        |                  ('RGB Lighting', 'UPS', 'USB Hub')                 |    18   |
# |       3        |                  ('RGB Lighting', 'UPS', 'Webcam')                  |    15   |
# |       3        |                ('RGB Lighting', 'USB Hub', 'Webcam')                |    14   |
# |       3        |                  ('SSD', 'Sound Card', 'Speakers')                  |    15   |
# |       3        |               ('SSD', 'Sound Card', 'Surge Protector')              |    12   |
# |       3        |                ('SSD', 'Sound Card', 'Thermal Paste')               |    20   |
# |       3        |                     ('SSD', 'Sound Card', 'UPS')                    |    18   |
# |       3        |                   ('SSD', 'Sound Card', 'USB Hub')                  |    22   |
# |       3        |                   ('SSD', 'Sound Card', 'Webcam')                   |    16   |
# |       3        |                ('SSD', 'Speakers', 'Surge Protector')               |    17   |
# |       3        |                 ('SSD', 'Speakers', 'Thermal Paste')                |    15   |
# |       3        |                      ('SSD', 'Speakers', 'UPS')                     |    14   |
# |       3        |                    ('SSD', 'Speakers', 'USB Hub')                   |    20   |
# |       3        |                    ('SSD', 'Speakers', 'Webcam')                    |    18   |
# |       3        |             ('SSD', 'Surge Protector', 'Thermal Paste')             |    14   |
# |       3        |                  ('SSD', 'Surge Protector', 'UPS')                  |    17   |
# |       3        |                ('SSD', 'Surge Protector', 'USB Hub')                |    25   |
# |       3        |                 ('SSD', 'Surge Protector', 'Webcam')                |    21   |
# |       3        |                   ('SSD', 'Thermal Paste', 'UPS')                   |    16   |
# |       3        |                 ('SSD', 'Thermal Paste', 'USB Hub')                 |    18   |
# |       3        |                  ('SSD', 'Thermal Paste', 'Webcam')                 |    22   |
# |       3        |                      ('SSD', 'UPS', 'USB Hub')                      |    15   |
# |       3        |                       ('SSD', 'UPS', 'Webcam')                      |    12   |
# |       3        |                     ('SSD', 'USB Hub', 'Webcam')                    |    18   |
# |       3        |            ('Sound Card', 'Speakers', 'Surge Protector')            |    15   |
# |       3        |             ('Sound Card', 'Speakers', 'Thermal Paste')             |    21   |
# |       3        |                  ('Sound Card', 'Speakers', 'UPS')                  |    26   |
# |       3        |                ('Sound Card', 'Speakers', 'USB Hub')                |    16   |
# |       3        |                 ('Sound Card', 'Speakers', 'Webcam')                |    24   |
# |       3        |          ('Sound Card', 'Surge Protector', 'Thermal Paste')         |    12   |
# |       3        |               ('Sound Card', 'Surge Protector', 'UPS')              |    23   |
# |       3        |             ('Sound Card', 'Surge Protector', 'USB Hub')            |    19   |
# |       3        |             ('Sound Card', 'Surge Protector', 'Webcam')             |    19   |
# |       3        |                ('Sound Card', 'Thermal Paste', 'UPS')               |    24   |
# |       3        |              ('Sound Card', 'Thermal Paste', 'USB Hub')             |    18   |
# |       3        |              ('Sound Card', 'Thermal Paste', 'Webcam')              |    16   |
# |       3        |                   ('Sound Card', 'UPS', 'USB Hub')                  |    20   |
# |       3        |                   ('Sound Card', 'UPS', 'Webcam')                   |    16   |
# |       3        |                 ('Sound Card', 'USB Hub', 'Webcam')                 |    12   |
# |       3        |           ('Speakers', 'Surge Protector', 'Thermal Paste')          |    15   |
# |       3        |                ('Speakers', 'Surge Protector', 'UPS')               |    20   |
# |       3        |              ('Speakers', 'Surge Protector', 'USB Hub')             |    19   |
# |       3        |              ('Speakers', 'Surge Protector', 'Webcam')              |    22   |
# |       3        |                 ('Speakers', 'Thermal Paste', 'UPS')                |    17   |
# |       3        |               ('Speakers', 'Thermal Paste', 'USB Hub')              |    16   |
# |       3        |               ('Speakers', 'Thermal Paste', 'Webcam')               |    15   |
# |       3        |                    ('Speakers', 'UPS', 'USB Hub')                   |    15   |
# |       3        |                    ('Speakers', 'UPS', 'Webcam')                    |    13   |
# |       3        |                  ('Speakers', 'USB Hub', 'Webcam')                  |    12   |
# |       3        |             ('Surge Protector', 'Thermal Paste', 'UPS')             |    17   |
# |       3        |           ('Surge Protector', 'Thermal Paste', 'USB Hub')           |    13   |
# |       3        |            ('Surge Protector', 'Thermal Paste', 'Webcam')           |    18   |
# |       3        |                ('Surge Protector', 'UPS', 'USB Hub')                |    21   |
# |       3        |                 ('Surge Protector', 'UPS', 'Webcam')                |    18   |
# |       3        |               ('Surge Protector', 'USB Hub', 'Webcam')              |    24   |
# |       3        |                 ('Thermal Paste', 'UPS', 'USB Hub')                 |    19   |
# |       3        |                  ('Thermal Paste', 'UPS', 'Webcam')                 |    14   |
# |       3        |                ('Thermal Paste', 'USB Hub', 'Webcam')               |    10   |
# |       4        |        ('CPU', 'CPU Cooler', 'Cooling Fan', 'Optical Drive')        |    10   |
# |       4        |                  ('CPU', 'Case', 'RAM', 'USB Hub')                  |    10   |
# |       4        |        ('CPU', 'Cooling Fan', 'External HDD', 'RGB Lighting')       |    10   |
# |       4        |             ('CPU', 'Cooling Fan', 'GPU', 'Motherboard')            |    10   |
# |       4        |            ('CPU', 'Cooling Fan', 'GPU', 'Network Card')            |    10   |
# |       4        |         ('CPU', 'Cooling Fan', 'Graphics Tablet', 'Monitor')        |    12   |
# |       4        |       ('CPU', 'Cooling Fan', 'Graphics Tablet', 'Motherboard')      |    12   |
# |       4        |          ('CPU', 'Cooling Fan', 'Graphics Tablet', 'Mouse')         |    10   |
# |       4        |           ('CPU', 'Cooling Fan', 'Monitor', 'Motherboard')          |    10   |
# |       4        |          ('CPU', 'Cooling Fan', 'Monitor', 'Optical Drive')         |    10   |
# |       4        |            ('CPU', 'Cooling Fan', 'Motherboard', 'Mouse')           |    10   |
# |       4        |        ('CPU', 'Cooling Fan', 'Motherboard', 'Network Card')        |    11   |
# |       4        |        ('CPU', 'Cooling Fan', 'Motherboard', 'Optical Drive')       |    11   |
# |       4        |        ('CPU', 'Cooling Fan', 'Motherboard', 'Power Supply')        |    10   |
# |       4        |         ('CPU', 'Cooling Fan', 'Motherboard', 'Sound Card')         |    10   |
# |       4        |             ('CPU', 'External HDD', 'Mouse', 'USB Hub')             |    11   |
# |       4        |               ('CPU', 'GPU', 'Monitor', 'Motherboard')              |    11   |
# |       4        |             ('CPU', 'GPU', 'Network Card', 'Sound Card')            |    10   |
# |       4        |           ('CPU', 'Headset', 'Network Card', 'Sound Card')          |    11   |
# |       4        |            ('CPU', 'Headset', 'RGB Lighting', 'USB Hub')            |    10   |
# |       4        |          ('CPU', 'Keyboard', 'Power Supply', 'Sound Card')          |    11   |
# |       4        |          ('CPU', 'Monitor', 'Motherboard', 'Network Card')          |    10   |
# |       4        |           ('CPU', 'Monitor', 'Network Card', 'Sound Card')          |    10   |
# |       4        |        ('CPU', 'Power Supply', 'RGB Lighting', 'Sound Card')        |    10   |
# |       4        |    ('CPU Cooler', 'Cooling Fan', 'External HDD', 'RGB Lighting')    |    10   |
# |       4        |             ('CPU Cooler', 'GPU', 'Motherboard', 'RAM')             |    11   |
# |       4        |           ('Case', 'External HDD', 'Power Supply', 'UPS')           |    10   |
# |       4        |                ('Case', 'GPU', 'Mouse', 'Sound Card')               |    10   |
# |       4        |             ('Case', 'Monitor', 'Thermal Paste', 'UPS')             |    10   |
# |       4        |               ('Case', 'Motherboard', 'SSD', 'Webcam')              |    11   |
# |       4        |            ('Cooling Fan', 'External HDD', 'HDD', 'UPS')            |    10   |
# |       4        |           ('Cooling Fan', 'GPU', 'Monitor', 'Motherboard')          |    10   |
# |       4        |           ('Cooling Fan', 'GPU', 'Monitor', 'Sound Card')           |    10   |
# |       4        |          ('Cooling Fan', 'HDD', 'Headset', 'Optical Drive')         |    11   |
# |       4        |      ('Cooling Fan', 'Headset', 'Sound Card', 'Thermal Paste')      |    10   |
# |       4        |  ('Cooling Fan', 'Network Card', 'Optical Drive', 'Thermal Paste')  |    11   |
# |       4        |   ('Cooling Fan', 'Optical Drive', 'Sound Card', 'Thermal Paste')   |    12   |
# |       4        |       ('Cooling Fan', 'Surge Protector', 'USB Hub', 'Webcam')       |    11   |
# |       4        |            ('External HDD', 'GPU', 'Speakers', 'Webcam')            |    11   |
# |       4        |      ('External HDD', 'HDD', 'Network Card', 'Surge Protector')     |    11   |
# |       4        |            ('External HDD', 'HDD', 'Power Supply', 'UPS')           |    10   |
# |       4        |            ('External HDD', 'HDD', 'RGB Lighting', 'UPS')           |    10   |
# |       4        |          ('External HDD', 'HDD', 'Surge Protector', 'UPS')          |    11   |
# |       4        |          ('External HDD', 'Headset', 'Power Supply', 'UPS')         |    10   |
# |       4        |        ('External HDD', 'Motherboard', 'Network Card', 'SSD')       |    10   |
# |       4        |        ('External HDD', 'Motherboard', 'Power Supply', 'UPS')       |    10   |
# |       4        |          ('External HDD', 'Motherboard', 'SSD', 'Speakers')         |    10   |
# |       4        |            ('External HDD', 'Network Card', 'RAM', 'UPS')           |    10   |
# |       4        |      ('External HDD', 'Network Card', 'Surge Protector', 'UPS')     |    10   |
# |       4        |         ('External HDD', 'RAM', 'RGB Lighting', 'Speakers')         |    10   |
# |       4        |          ('External HDD', 'SSD', 'Thermal Paste', 'Webcam')         |    11   |
# |       4        |           ('GPU', 'Headset', 'RGB Lighting', 'Sound Card')          |    10   |
# |       4        |            ('GPU', 'Motherboard', 'Sound Card', 'Webcam')           |    10   |
# |       4        |              ('GPU', 'Mouse', 'Surge Protector', 'UPS')             |    11   |
# |       4        |               ('GPU', 'RAM', 'Sound Card', 'Speakers')              |    10   |
# |       4        |         ('GPU', 'Sound Card', 'Speakers', 'Surge Protector')        |    10   |
# |       4        |               ('GPU', 'Sound Card', 'Speakers', 'UPS')              |    10   |
# |       4        |             ('GPU', 'Sound Card', 'Speakers', 'Webcam')             |    13   |
# |       4        |          ('GPU', 'Sound Card', 'Surge Protector', 'Webcam')         |    14   |
# |       4        |           ('GPU', 'Speakers', 'Surge Protector', 'Webcam')          |    10   |
# |       4        |            ('HDD', 'Motherboard', 'RGB Lighting', 'UPS')            |    10   |
# |       4        |              ('HDD', 'Optical Drive', 'SSD', 'Webcam')              |    10   |
# |       4        |             ('HDD', 'RAM', 'RGB Lighting', 'Sound Card')            |    10   |
# |       4        |           ('HDD', 'RGB Lighting', 'Sound Card', 'Webcam')           |    10   |
# |       4        |          ('HDD', 'RGB Lighting', 'Surge Protector', 'UPS')          |    10   |
# |       4        |            ('Headset', 'Keyboard', 'Motherboard', 'UPS')            |    10   |
# |       4        |              ('Headset', 'Motherboard', 'Mouse', 'RAM')             |    10   |
# |       4        |         ('Headset', 'Motherboard', 'Surge Protector', 'UPS')        |    10   |
# |       4        |          ('Keyboard', 'Motherboard', 'Network Card', 'SSD')         |    10   |
# |       4        |            ('Keyboard', 'RAM', 'Surge Protector', 'UPS')            |    10   |
# |       4        |         ('Monitor', 'Mouse', 'Optical Drive', 'Sound Card')         |    10   |
# |       4        |        ('Monitor', 'RGB Lighting', 'Surge Protector', 'UPS')        |    11   |
# |       4        |        ('Motherboard', 'Mouse', 'Surge Protector', 'Webcam')        |    10   |
# |       4        | ('Motherboard', 'Power Supply', 'Surge Protector', 'Thermal Paste') |    10   |
# |       4        |          ('Motherboard', 'SSD', 'Thermal Paste', 'Webcam')          |    10   |
# |       4        |    ('Motherboard', 'Surge Protector', 'Thermal Paste', 'Webcam')    |    11   |
# |       4        |      ('Mouse', 'Optical Drive', 'Sound Card', 'Thermal Paste')      |    10   |
# |       4        |         ('Mouse', 'Power Supply', 'Surge Protector', 'UPS')         |    10   |
# |       4        |       ('Optical Drive', 'RGB Lighting', 'Speakers', 'USB Hub')      |    10   |
# |       4        |         ('Optical Drive', 'SSD', 'Thermal Paste', 'Webcam')         |    10   |
# |       4        |           ('RAM', 'RGB Lighting', 'Thermal Paste', 'UPS')           |    10   |
# |       4        |               ('RAM', 'Sound Card', 'Speakers', 'UPS')              |    11   |
# +----------------+---------------------------------------------------------------------+---------+

# %%
freq_df.head()
# Out:
#    Itemset Number       Itemset  Support
# 0               1           CPU      266
# 1               1    CPU Cooler      244
# 2               1          Case      245
# 3               1   Cooling Fan      248
# 4               1  External HDD      250

# %%
freq_df.to_csv('Frequent Itemsets.csv')

# %%
for key in L:
    print(f"Maximum {key}-itemset is:")
    keyValMax = max(zip(L[key].values(), L[key].keys()))
    print(f"Itemset: {keyValMax[1]} ...... Support Count: {keyValMax[0]}")
# Out:
# Maximum 1-itemset is:
# Itemset: Sound Card ...... Support Count: 284
# Maximum 2-itemset is:
# Itemset: ('CPU', 'Sound Card') ...... Support Count: 84
# Maximum 3-itemset is:
# Itemset: ('External HDD', 'Power Supply', 'UPS') ...... Support Count: 28
# Maximum 4-itemset is:
# Itemset: ('GPU', 'Sound Card', 'Surge Protector', 'Webcam') ...... Support Count: 14
